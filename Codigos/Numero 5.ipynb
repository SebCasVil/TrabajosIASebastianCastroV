# %%
import cv2 as cv
import numpy as np

# %%
# APLICAR FILTROS DE COLOR
img = cv.imread('C:/Users/kalan/Desktop/nabo.jpg',1)

zeros = np.zeros(img.shape[:2], dtype='uint8')
imgN = cv.cvtColor(img, cv.COLOR_BGR2RGB)
(b,g,r) = cv.split(img)

cv.imshow('b',b)
cv.imshow('g',g)
cv.imshow('r',r)

cv.imshow('b1', cv.merge([b,zeros,zeros]))
cv.imshow('g1', cv.merge([zeros,g,zeros]))
cv.imshow('r1', cv.merge([zeros,zeros,r]))

cv.imshow('img', img)
cv.imshow('imgN', imgN)
cv.imshow('zeros', zeros)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
# FILTRAR VALORES DE LA IMAGEN Y OBTENER DATOS PERSONALIZADOS
img = cv.imread('C:/Users/kalan/Desktop/nabo.jpg',0)

w,h = (img.shape)
img1 = img.copy()
img2 = img.copy()
img3 = img.copy()
img4 = img.copy()
img5 = img.copy()

#for i in range(w):
#    for j in range(h):
        #if(img[i,j] > 150):
#        img[i,j]=255-img[i,j]
        #else:
            #img[i,j]=0

for i in range(w):
    for j in range(h):
            img1[i,j]= img1[i,j]-100

for i in range(w):
    for j in range(h):
            img2[i,j]= img2[i,j]+100

for i in range(w):
    for j in range(h):
        if (img3[i,j] > 200):
            img3[i,j]= 1
            
for i in range(w):
    for j in range(h):
        if (img4[i,j] < 200):
            img4[i,j]= 1

for i in range(w):
    for j in range(h):
        if (img5[i,j] > 200):
            img5[i,j]= 100



cv.imshow('Img1', img1)
cv.imshow('Img2', img2)
cv.imshow('Img3', img3)
cv.imshow('Img4', img4)
cv.imshow('Img5', img2)

#cv.imshow('Ejemplo', img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\kalan\Desktop\IA\git\TrabajosIASebastianCastroV\04-09-2023.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # FILTRAR VALORES DE LA IMAGEN Y OBTENER DATOS PERSONALIZADOS
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> img = cv.imread('C:/Users/kalan/Desktop/nabo.jpg',0)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> w,h = (img.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> img1 = img.copy()
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> img2 = img.copy()
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
pwd //

# %%
# MODELO DE COLOR HSV 05/09/2023

cap = cv.VideoCapture(0)

img1 = cap.read()
img2 = cv.cvtColor(img1, cv.COLOR_BGR2RGB) 
img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralBajo = (0, 80, 80)
umbralAlto = (10, 255, 255)
umbralBajoB = (170, 80, 80)
umbralAltoB = (180, 255,255)

mascara1 = cv.inRange(img3, umbralBajo, umbralAlto)
mascara2 = cv.inRange(img3, umbralBajoB, umbralAltoB)

mascara  = mascara1+mascara2

resultado = cv.bitwise_and(img1, img1, mask=mascara)

cv.imshow('Img1', img1)
cv.imshow('Img2', img2)
cv.imshow('Img3', img3)
cv.imshow('mascara', mascara)
cv.imshow('resultado', resultado)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\kalan\Desktop\IA\git\TrabajosIASebastianCastroV\04-09-2023.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # MODELO DE COLOR HSV 05/09/2023
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> img1 = cv.VideoCapture(0)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> img2 = cv.cvtColor(img1, cv.COLOR_BGR2RGB)
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)
#       <a href='vscode-notebook-cell:/c%3A/Users/kalan/Desktop/IA/git/TrabajosIASebastianCastroV/04-09-2023.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> umbralBajo = (0, 80, 80)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
# OBTENER, FILTRAR Y MODIFICAR EN TIEMPO REAL
import cv2 as cv
import numpy as np

cap = cv.VideoCapture(0)
# cap = cv.VideoCapture('Dirección de video')

if not cap.isOpened():
    print("No se puede abrir la cámara")
    exit()
while True:
    ret, img1 = cap.read()
    img2 = cv.cvtColor(img1, cv.COLOR_BGR2RGB) 
    img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)
    
    umbralBajo = (150, 80, 80)
    umbralAlto = (160, 255, 255)
    # umbralBajoB = (170, 80, 80)
    # umbralAltoB = (180, 255,255)
    
    mascara1 = cv.inRange(img3, umbralBajo, umbralAlto)
    # mascara2 = cv.inRange(img3, umbralBajoB, umbralAltoB)
    
    # mascara  = mascara1+mascara2
    
    resultado = cv.bitwise_and(img1, img1, mask=mascara1)
    
    cv.imshow('Img1', img1)
    cv.imshow('Img2', img2)
    cv.imshow('Img3', img3)
    cv.imshow('mascara1', mascara1)
    cv.imshow('resultado', resultado)
    
    if not ret:
        print("No se pudo capturar fotogramas")
        break
    if cv.waitKey(10) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()

# %%
# OBTENER COORDENADAS DE UN COLOR ESPECÍFICO
import cv2 as cv
import numpy as np

img1 = cv.imread('C:/Users/kalan/Desktop/tr.png',1)
img2 = cv.cvtColor(img1, cv.COLOR_BGR2RGB) 
img3 = cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralBajoRojo = (0, 170, 170)
umbralAltoRojo = (5, 255, 255)

umbralBajoRojo2 = (175, 100, 100)
umbralAltoRojo2 = (180, 255, 255)



# umbralBajoAmarillo = (25, 80, 80)
# umbralAltoAmarillo = (35, 255, 255)

mascaraRoja = cv.inRange(img3, umbralBajoRojo, umbralAltoRojo)
mascaraRoja2 = cv.inRange(img3, umbralBajoRojo2, umbralAltoRojo2)

mascaraRojaFinal = cv.bitwise_or(mascaraRoja, mascaraRoja2)


# mascaraAmarilla = cv.inRange(img3, umbralBajoAmarillo, umbralAltoAmarillo)

resultadoRojo = cv.bitwise_and(img1, img1, mask=mascaraRojaFinal)
# resultadoAmarillo = cv.bitwise_and(img1, img1, mask=mascaraAmarilla)

contoursRojo, hierarchyRojo = cv.findContours(mascaraRojaFinal, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
print(contoursRojo)

# contoursAmarillo, hierarchyRojo = cv.findContours(mascaraAmarilla, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# print(contoursAmarillo)

# Contar el número de objetos rojos
num_objetos_rojos = len(contoursRojo)
print(f"Número de objetos rojos: {num_objetos_rojos}")

# Dibujar contornos azules en la imagen original
img_contornos = img1.copy()
cv.drawContours(img_contornos, contoursRojo, -1, (255, 0, 0), 2)  



cv.imshow('Img1', img1)
cv.imshow('mascaraRoja', mascaraRojaFinal)
# cv.imshow('mascaraAmarilla', mascaraAmarilla)
cv.imshow('resultadoRojo', resultadoRojo)
# cv.imshow('resultadoAmarillo', resultadoAmarillo)
cv.imshow('contornos', img_contornos)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (array([[[610, 615]],
#
#        [[610, 616]],
#
#        [[611, 617]],
#
#        [[610, 618]],
#
#        [[609, 618]],
#
#        [[609, 619]],
#
#        [[608, 620]],
#
#        [[606, 620]],
#
#        [[606, 621]],
#
#        [[604, 623]],
#
#        [[602, 623]],
#
#        [[601, 624]],
#
#        [[602, 625]],
#
#        [[602, 626]],
#
#        [[608, 626]],
#
#        [[608, 625]],
#
#        [[609, 624]],
#
#        [[610, 624]],
#
#        [[610, 622]],
#
#        [[611, 621]],
#
#        [[612, 621]],
#
#        [[612, 617]],
#
#        [[611, 617]],
#
#        [[610, 616]]], dtype=int32), array([[[168, 615]],
#
#        [[168, 618]],
#
#        [[170, 618]],
#
#        [[170, 615]]], dtype=int32), array([[[396, 609]]], dtype=int32), array([[[176, 609]],
#
#        [[174, 611]],
#
#        [[173, 611]],
#
#        [[173, 612]],
#
#        [[174, 612]],
#
#        [[175, 613]],
#
#        [[175, 614]],
#
#        [[176, 615]],
#
#        [[176, 617]],
#
#        [[175, 618]],
#
#        [[175, 621]],
#
#        [[176, 621]],
#
#        [[177, 622]],
#
#        [[178, 622]],
#
#        [[179, 621]],
#
#        [[179, 619]],
#
#        [[180, 618]],
#
#        [[179, 617]],
#
#        [[177, 617]],
#
#        [[176, 616]],
#
#        [[176, 615]],
#
#        [[177, 614]],
#
#        [[178, 614]],
#
#        [[178, 609]]], dtype=int32), array([[[375, 608]]], dtype=int32), array([[[427, 606]],
#
#        [[427, 608]],
#
#        [[426, 609]],
#
#        [[426, 612]],
#
#        [[428, 612]],
#
#        [[429, 613]],
#
#        [[430, 613]],
#
#        [[431, 614]],
#
#        [[431, 617]],
#
#        [[432, 617]],
#
#        [[433, 618]],
#
#        [[432, 619]],
#
#        [[431, 619]],
#
#        [[431, 623]],
#
#        [[432, 623]],
#
#        [[434, 625]],
#
#        [[434, 626]],
#
#        [[453, 626]],
#
#        [[453, 625]],
#
#        [[454, 624]],
#
#        [[456, 624]],
#
#        [[458, 622]],
#
#        [[458, 618]],
#
#        [[459, 617]],
#
#        [[460, 617]],
#
#        [[460, 613]],
#
#        [[459, 613]],
#
#        [[458, 612]],
#
#        [[458, 611]],
#
#        [[459, 610]],
#
#        [[460, 610]],
#
#        [[458, 610]],
#
#        [[457, 609]],
#
#        [[457, 606]],
#
#        [[457, 607]],
#
#        [[456, 608]],
#
#        [[456, 609]],
#
#        [[455, 610]],
#
#        [[454, 610]],
#
#        [[453, 611]],
#
#        [[451, 609]],
#
#        [[448, 609]],
#
#        [[447, 610]],
#
#        [[447, 613]],
#
#        [[446, 614]],
#
#        [[445, 614]],
#
#        [[443, 612]],
#
#        [[443, 610]],
#
#        [[438, 610]],
#
#        [[437, 609]],
#
#        [[436, 609]],
#
#        [[435, 608]],
#
#        [[435, 610]],
#
#        [[434, 611]],
#
#        [[434, 612]],
#
#        [[433, 613]],
#
#        [[432, 612]],
#
#        [[432, 608]],
#
#        [[431, 608]],
#
#        [[430, 607]],
#
#        [[430, 606]]], dtype=int32), array([[[442, 617]],
#
#        [[443, 616]],
#
#        [[444, 617]],
#
#        [[443, 618]]], dtype=int32), array([[[479, 605]]], dtype=int32), array([[[459, 605]],
#
#        [[460, 605]]], dtype=int32), array([[[367, 605]],
#
#        [[366, 606]],
#
#        [[366, 607]],
#
#        [[364, 609]],
#
#        [[362, 609]],
#
#        [[363, 609]],
#
#        [[364, 610]],
#
#        [[363, 611]],
#
#        [[362, 611]],
#
#        [[362, 613]],
#
#        [[363, 613]],
#
#        [[364, 614]],
#
#        [[365, 613]],
#
#        [[366, 613]],
#
#        [[367, 614]],
#
#        [[372, 614]],
#
#        [[374, 612]],
#
#        [[374, 611]],
#
#        [[373, 610]],
#
#        [[373, 608]],
#
#        [[371, 608]],
#
#        [[370, 607]],
#
#        [[370, 605]]], dtype=int32), array([[[363, 613]],
#
#        [[364, 612]],
#
#        [[365, 613]],
#
#        [[364, 614]]], dtype=int32), array([[[344, 605]],
#
#        [[343, 606]],
#
#        [[343, 607]],
#
#        [[342, 608]],
#
#        [[344, 610]],
#
#        [[350, 610]],
#
#        [[351, 611]],
#
#        [[351, 612]],
#
#        [[354, 612]],
#
#        [[355, 613]],
#
#        [[355, 611]],
#
#        [[354, 610]],
#
#        [[354, 609]],
#
#        [[353, 609]],
#
#        [[351, 607]],
#
#        [[351, 605]],
#
#        [[347, 605]],
#
#        [[346, 606]],
#
#        [[345, 605]]], dtype=int32), array([[[342, 608]],
#
#        [[343, 607]],
#
#        [[344, 608]],
#
#        [[343, 609]]], dtype=int32), array([[[472, 604]],
#
#        [[474, 604]]], dtype=int32), array([[[366, 602]],
#
#        [[366, 603]]], dtype=int32), array([[[351, 602]],
#
#        [[351, 603]]], dtype=int32), array([[[457, 601]],
#
#        [[457, 603]],
#
#        [[458, 603]],
#
#        [[458, 602]]], dtype=int32), array([[[493, 597]],
#
#        [[493, 598]]], dtype=int32), array([[[462, 596]],
#
#        [[462, 598]],
#
#        [[463, 598]],
#
#        [[463, 596]]], dtype=int32), array([[[447, 595]],
#
#        [[446, 596]],
#
#        [[445, 596]],
#
#        [[446, 596]],
#
#        [[447, 597]],
#
#        [[447, 598]],
#
#        [[451, 598]],
#
#        [[451, 595]]], dtype=int32), array([[[499, 592]],
#
#        [[499, 593]],
#
#        [[498, 594]],
#
#        [[499, 593]]], dtype=int32), array([[[412, 592]],
#
#        [[412, 593]],
#
#        [[410, 595]],
#
#        [[408, 595]],
#
#        [[406, 597]],
#
#        [[406, 598]],
#
#        [[405, 599]],
#
#        [[403, 599]],
#
#        [[401, 601]],
#
#        [[399, 601]],
#
#        [[399, 603]],
#
#        [[401, 603]],
#
#        [[402, 604]],
#
#        [[401, 605]],
#
#        [[401, 607]],
#
#        [[400, 608]],
#
#        [[398, 608]],
#
#        [[398, 610]],
#
#        [[399, 611]],
#
#        [[399, 612]],
#
#        [[398, 613]],
#
#        [[398, 622]],
#
#        [[397, 623]],
#
#        [[397, 624]],
#
#        [[398, 623]],
#
#        [[399, 624]],
#
#        [[405, 624]],
#
#        [[407, 622]],
#
#        [[404, 622]],
#
#        [[403, 621]],
#
#        [[403, 619]],
#
#        [[404, 618]],
#
#        [[405, 618]],
#
#        [[405, 615]],
#
#        [[406, 614]],
#
#        [[406, 611]],
#
#        [[407, 610]],
#
#        [[414, 610]],
#
#        [[415, 609]],
#
#        [[417, 611]],
#
#        [[417, 612]],
#
#        [[419, 612]],
#
#        [[419, 608]],
#
#        [[420, 607]],
#
#        [[420, 605]],
#
#        [[421, 604]],
#
#        [[421, 602]],
#
#        [[422, 601]],
#
#        [[423, 601]],
#
#        [[423, 595]],
#
#        [[422, 595]],
#
#        [[421, 594]],
#
#        [[420, 594]],
#
#        [[419, 593]],
#
#        [[419, 592]]], dtype=int32), array([[[407, 604]],
#
#        [[408, 603]],
#
#        [[409, 603]],
#
#        [[410, 604]],
#
#        [[410, 605]],
#
#        [[409, 606]],
#
#        [[408, 606]],
#
#        [[407, 605]]], dtype=int32), array([[[419, 599]],
#
#        [[420, 598]],
#
#        [[421, 599]],
#
#        [[420, 600]]], dtype=int32), array([[[415, 597]],
#
#        [[416, 596]],
#
#        [[419, 596]],
#
#        [[420, 597]],
#
#        [[420, 598]],
#
#        [[418, 600]],
#
#        [[417, 600]],
#
#        [[416, 601]],
#
#        [[415, 601]],
#
#        [[414, 600]],
#
#        [[414, 599]],
#
#        [[415, 598]]], dtype=int32), array([[[501, 590]],
#
#        [[502, 590]]], dtype=int32), array([[[491, 590]],
#
#        [[492, 590]]], dtype=int32), array([[[480, 590]]], dtype=int32), array([[[466, 587]]], dtype=int32), array([[[484, 586]]], dtype=int32), array([[[482, 582]],
#
#        [[481, 583]],
#
#        [[481, 584]],
#
#        [[481, 583]],
#
#        [[482, 582]],
#
#        [[483, 582]]], dtype=int32), array([[[480, 581]]], dtype=int32), array([[[230, 581]],
#
#        [[230, 582]],
#
#        [[231, 583]],
#
#        [[231, 584]],
#
#        [[234, 584]],
#
#        [[237, 587]],
#
#        [[245, 587]],
#
#        [[246, 586]],
#
#        [[241, 586]],
#
#        [[240, 585]],
#
#        [[235, 585]],
#
#        [[234, 584]],
#
#        [[234, 583]],
#
#        [[235, 582]],
#
#        [[236, 582]],
#
#        [[235, 582]],
#
#        [[234, 583]],
#
#        [[232, 583]]], dtype=int32), array([[[475, 577]],
#
#        [[474, 578]],
#
#        [[473, 578]],
#
#        [[475, 578]]], dtype=int32), array([[[133, 573]],
#
#        [[134, 573]]], dtype=int32), array([[[481, 572]],
#
#        [[483, 572]]], dtype=int32), array([[[139, 572]],
#
#        [[138, 573]],
#
#        [[139, 573]]], dtype=int32), array([[[487, 571]],
#
#        [[487, 572]],
#
#        [[488, 572]],
#
#        [[488, 571]]], dtype=int32), array([[[ 97, 568]],
#
#        [[ 97, 572]],
#
#        [[ 96, 573]],
#
#        [[ 97, 573]],
#
#        [[ 98, 574]],
#
#        [[ 98, 575]],
#
#        [[102, 575]],
#
#        [[102, 574]],
#
#        [[103, 573]],
#
#        [[104, 573]],
#
#        [[104, 572]],
#
#        [[105, 571]],
#
#        [[106, 571]],
#
#        [[105, 571]],
#
#        [[104, 570]],
#
#        [[104, 568]],
#
#        [[103, 568]],
#
#        [[102, 569]],
#
#        [[101, 568]]], dtype=int32), array([[[102, 571]],
#
#        [[103, 570]],
#
#        [[104, 570]],
#
#        [[105, 571]],
#
#        [[104, 572]],
#
#        [[103, 572]]], dtype=int32), array([[[290, 563]]], dtype=int32), array([[[278, 557]]], dtype=int32), array([[[277, 554]]], dtype=int32), array([[[230, 542]],
#
#        [[230, 543]],
#
#        [[235, 543]],
#
#        [[236, 544]],
#
#        [[240, 544]],
#
#        [[241, 543]],
#
#        [[248, 543]],
#
#        [[248, 542]]], dtype=int32), array([[[265, 540]],
#
#        [[264, 541]],
#
#        [[260, 541]],
#
#        [[266, 541]],
#
#        [[267, 540]]], dtype=int32), array([[[222, 540]],
#
#        [[221, 541]],
#
#        [[221, 543]],
#
#        [[225, 543]],
#
#        [[225, 542]],
#
#        [[222, 542]],
#
#        [[221, 541]]], dtype=int32), array([[[413, 525]],
#
#        [[412, 526]],
#
#        [[413, 527]],
#
#        [[414, 527]],
#
#        [[415, 528]],
#
#        [[415, 529]],
#
#        [[414, 530]],
#
#        [[413, 530]],
#
#        [[416, 530]],
#
#        [[417, 529]],
#
#        [[419, 529]],
#
#        [[419, 527]],
#
#        [[420, 526]],
#
#        [[419, 527]],
#
#        [[417, 527]],
#
#        [[416, 526]],
#
#        [[416, 525]]], dtype=int32), array([[[431, 522]],
#
#        [[433, 522]]], dtype=int32), array([[[245, 520]],
#
#        [[245, 521]],
#
#        [[246, 521]],
#
#        [[246, 520]]], dtype=int32), array([[[384, 518]],
#
#        [[384, 520]],
#
#        [[383, 521]],
#
#        [[384, 521]],
#
#        [[385, 522]],
#
#        [[385, 524]],
#
#        [[389, 524]],
#
#        [[389, 523]],
#
#        [[390, 522]],
#
#        [[391, 522]],
#
#        [[391, 518]]], dtype=int32), array([[[388, 521]],
#
#        [[389, 520]],
#
#        [[390, 521]],
#
#        [[389, 522]]], dtype=int32), array([[[387, 520]],
#
#        [[388, 519]],
#
#        [[389, 520]],
#
#        [[388, 521]]], dtype=int32), array([[[584, 517]],
#
#        [[583, 518]],
#
#        [[582, 518]],
#
#        [[582, 521]],
#
#        [[583, 522]],
#
#        [[583, 521]],
#
#        [[584, 520]],
#
#        [[585, 520]],
#
#        [[586, 521]],
#
#        [[586, 522]],
#
#        [[589, 522]],
#
#        [[589, 518]],
#
#        [[588, 518]],
#
#        [[587, 517]]], dtype=int32), array([[[433, 514]],
#
#        [[433, 515]],
#
#        [[432, 516]],
#
#        [[431, 516]],
#
#        [[431, 517]],
#
#        [[430, 518]],
#
#        [[430, 520]],
#
#        [[431, 519]],
#
#        [[433, 519]],
#
#        [[434, 520]],
#
#        [[435, 520]],
#
#        [[436, 519]],
#
#        [[437, 519]],
#
#        [[437, 517]],
#
#        [[436, 517]],
#
#        [[434, 515]],
#
#        [[434, 514]]], dtype=int32), array([[[583, 504]],
#
#        [[584, 505]],
#
#        [[584, 506]],
#
#        [[586, 506]],
#
#        [[588, 508]],
#
#        [[591, 508]],
#
#        [[592, 509]],
#
#        [[592, 510]],
#
#        [[593, 511]],
#
#        [[594, 511]],
#
#        [[593, 511]],
#
#        [[592, 510]],
#
#        [[592, 508]],
#
#        [[591, 507]],
#
#        [[588, 507]],
#
#        [[587, 506]],
#
#        [[587, 505]],
#
#        [[584, 505]]], dtype=int32), array([[[412, 504]]], dtype=int32), array([[[397, 504]],
#
#        [[396, 505]],
#
#        [[394, 505]],
#
#        [[394, 506]],
#
#        [[396, 506]],
#
#        [[397, 507]],
#
#        [[398, 507]],
#
#        [[399, 508]],
#
#        [[398, 509]],
#
#        [[398, 510]],
#
#        [[398, 509]],
#
#        [[399, 508]],
#
#        [[400, 508]],
#
#        [[400, 507]],
#
#        [[401, 506]],
#
#        [[401, 505]],
#
#        [[398, 505]]], dtype=int32), array([[[108, 504]],
#
#        [[109, 504]]], dtype=int32), array([[[591, 498]],
#
#        [[592, 498]],
#
#        [[593, 499]],
#
#        [[593, 501]],
#
#        [[594, 501]],
#
#        [[595, 502]],
#
#        [[597, 502]],
#
#        [[597, 500]],
#
#        [[597, 501]],
#
#        [[596, 502]],
#
#        [[595, 502]],
#
#        [[594, 501]],
#
#        [[594, 499]],
#
#        [[595, 498]],
#
#        [[594, 499]],
#
#        [[593, 499]],
#
#        [[592, 498]]], dtype=int32), array([[[110, 489]],
#
#        [[110, 493]],
#
#        [[111, 494]],
#
#        [[111, 496]],
#
#        [[110, 497]],
#
#        [[107, 497]],
#
#        [[107, 499]],
#
#        [[108, 500]],
#
#        [[108, 501]],
#
#        [[109, 501]],
#
#        [[109, 499]],
#
#        [[110, 498]],
#
#        [[111, 498]],
#
#        [[112, 499]],
#
#        [[112, 504]],
#
#        [[114, 504]],
#
#        [[115, 505]],
#
#        [[115, 506]],
#
#        [[116, 506]],
#
#        [[116, 505]],
#
#        [[117, 504]],
#
#        [[118, 504]],
#
#        [[118, 502]],
#
#        [[117, 502]],
#
#        [[116, 501]],
#
#        [[116, 500]],
#
#        [[117, 499]],
#
#        [[118, 499]],
#
#        [[119, 498]],
#
#        [[120, 498]],
#
#        [[121, 499]],
#
#        [[121, 501]],
#
#        [[120, 502]],
#
#        [[122, 504]],
#
#        [[122, 511]],
#
#        [[120, 513]],
#
#        [[120, 515]],
#
#        [[119, 516]],
#
#        [[119, 519]],
#
#        [[118, 520]],
#
#        [[115, 520]],
#
#        [[114, 519]],
#
#        [[114, 517]],
#
#        [[113, 517]],
#
#        [[112, 516]],
#
#        [[112, 514]],
#
#        [[111, 514]],
#
#        [[111, 517]],
#
#        [[112, 518]],
#
#        [[112, 520]],
#
#        [[116, 520]],
#
#        [[117, 521]],
#
#        [[120, 521]],
#
#        [[121, 522]],
#
#        [[124, 522]],
#
#        [[124, 520]],
#
#        [[123, 519]],
#
#        [[123, 517]],
#
#        [[125, 515]],
#
#        [[128, 515]],
#
#        [[128, 513]],
#
#        [[129, 512]],
#
#        [[132, 512]],
#
#        [[133, 511]],
#
#        [[137, 511]],
#
#        [[137, 507]],
#
#        [[138, 506]],
#
#        [[138, 505]],
#
#        [[138, 506]],
#
#        [[137, 507]],
#
#        [[136, 507]],
#
#        [[135, 506]],
#
#        [[135, 504]],
#
#        [[136, 503]],
#
#        [[137, 503]],
#
#        [[139, 501]],
#
#        [[139, 499]],
#
#        [[138, 499]],
#
#        [[137, 498]],
#
#        [[137, 495]],
#
#        [[136, 495]],
#
#        [[135, 494]],
#
#        [[134, 494]],
#
#        [[133, 493]],
#
#        [[133, 491]],
#
#        [[130, 491]],
#
#        [[129, 490]],
#
#        [[124, 490]],
#
#        [[123, 491]],
#
#        [[122, 491]],
#
#        [[120, 489]],
#
#        [[112, 489]],
#
#        [[111, 490]]], dtype=int32), array([[[124, 508]],
#
#        [[125, 507]],
#
#        [[126, 508]],
#
#        [[126, 510]],
#
#        [[125, 511]],
#
#        [[124, 510]]], dtype=int32), array([[[131, 502]],
#
#        [[132, 502]],
#
#        [[134, 504]],
#
#        [[134, 506]],
#
#        [[133, 507]],
#
#        [[130, 507]],
#
#        [[129, 506]],
#
#        [[129, 504]]], dtype=int32), array([[[127, 494]],
#
#        [[128, 493]],
#
#        [[129, 494]],
#
#        [[129, 496]],
#
#        [[128, 497]],
#
#        [[127, 496]]], dtype=int32), array([[[114, 493]],
#
#        [[115, 492]],
#
#        [[116, 493]],
#
#        [[116, 494]],
#
#        [[115, 495]],
#
#        [[114, 494]]], dtype=int32), array([[[ 87, 488]]], dtype=int32), array([[[597, 483]],
#
#        [[597, 489]],
#
#        [[598, 490]],
#
#        [[599, 490]],
#
#        [[600, 491]],
#
#        [[600, 492]],
#
#        [[601, 492]],
#
#        [[602, 493]],
#
#        [[603, 493]],
#
#        [[604, 492]],
#
#        [[604, 491]],
#
#        [[605, 490]],
#
#        [[606, 490]],
#
#        [[607, 489]],
#
#        [[608, 489]],
#
#        [[609, 488]],
#
#        [[609, 486]],
#
#        [[607, 486]],
#
#        [[606, 485]],
#
#        [[605, 485]],
#
#        [[604, 486]],
#
#        [[600, 486]],
#
#        [[599, 485]],
#
#        [[599, 484]],
#
#        [[598, 484]]], dtype=int32), array([[[ 62, 471]],
#
#        [[ 62, 473]],
#
#        [[ 61, 474]],
#
#        [[ 62, 475]],
#
#        [[ 62, 478]],
#
#        [[ 61, 479]],
#
#        [[ 60, 479]],
#
#        [[ 60, 484]],
#
#        [[ 61, 485]],
#
#        [[ 61, 487]],
#
#        [[ 60, 488]],
#
#        [[ 60, 490]],
#
#        [[ 61, 491]],
#
#        [[ 61, 493]],
#
#        [[ 62, 494]],
#
#        [[ 62, 496]],
#
#        [[ 63, 496]],
#
#        [[ 63, 494]],
#
#        [[ 64, 493]],
#
#        [[ 66, 495]],
#
#        [[ 66, 496]],
#
#        [[ 67, 496]],
#
#        [[ 67, 485]],
#
#        [[ 66, 485]],
#
#        [[ 65, 484]],
#
#        [[ 66, 483]],
#
#        [[ 67, 483]],
#
#        [[ 67, 472]],
#
#        [[ 66, 472]],
#
#        [[ 65, 471]]], dtype=int32), array([[[ 79, 463]],
#
#        [[ 79, 464]],
#
#        [[ 78, 465]],
#
#        [[ 78, 466]],
#
#        [[ 77, 467]],
#
#        [[ 76, 467]],
#
#        [[ 76, 469]],
#
#        [[ 75, 470]],
#
#        [[ 76, 471]],
#
#        [[ 76, 475]],
#
#        [[ 75, 476]],
#
#        [[ 76, 477]],
#
#        [[ 76, 478]],
#
#        [[ 74, 480]],
#
#        [[ 75, 481]],
#
#        [[ 75, 483]],
#
#        [[ 76, 484]],
#
#        [[ 76, 487]],
#
#        [[ 77, 487]],
#
#        [[ 77, 486]],
#
#        [[ 78, 485]],
#
#        [[ 78, 484]],
#
#        [[ 79, 483]],
#
#        [[ 79, 479]],
#
#        [[ 80, 478]],
#
#        [[ 81, 478]],
#
#        [[ 81, 477]],
#
#        [[ 82, 476]],
#
#        [[ 81, 475]],
#
#        [[ 81, 474]],
#
#        [[ 82, 473]],
#
#        [[ 82, 467]],
#
#        [[ 81, 466]],
#
#        [[ 81, 465]],
#
#        [[ 80, 465]],
#
#        [[ 79, 464]]], dtype=int32), array([[[ 47, 460]],
#
#        [[ 47, 464]],
#
#        [[ 46, 465]],
#
#        [[ 46, 466]],
#
#        [[ 47, 465]],
#
#        [[ 48, 466]],
#
#        [[ 48, 470]],
#
#        [[ 49, 470]],
#
#        [[ 50, 471]],
#
#        [[ 50, 474]],
#
#        [[ 49, 475]],
#
#        [[ 48, 475]],
#
#        [[ 47, 476]],
#
#        [[ 47, 480]],
#
#        [[ 48, 481]],
#
#        [[ 48, 485]],
#
#        [[ 49, 485]],
#
#        [[ 50, 486]],
#
#        [[ 50, 488]],
#
#        [[ 51, 489]],
#
#        [[ 52, 489]],
#
#        [[ 52, 481]],
#
#        [[ 51, 480]],
#
#        [[ 51, 471]],
#
#        [[ 50, 470]],
#
#        [[ 50, 460]]], dtype=int32), array([[[ 92, 458]],
#
#        [[ 92, 461]],
#
#        [[ 91, 462]],
#
#        [[ 91, 467]],
#
#        [[ 90, 468]],
#
#        [[ 89, 468]],
#
#        [[ 89, 476]],
#
#        [[ 88, 477]],
#
#        [[ 88, 484]],
#
#        [[ 88, 480]],
#
#        [[ 89, 479]],
#
#        [[ 90, 479]],
#
#        [[ 90, 475]],
#
#        [[ 91, 474]],
#
#        [[ 90, 473]],
#
#        [[ 90, 472]],
#
#        [[ 91, 471]],
#
#        [[ 91, 467]],
#
#        [[ 92, 466]],
#
#        [[ 91, 465]],
#
#        [[ 91, 462]],
#
#        [[ 92, 461]],
#
#        [[ 93, 462]],
#
#        [[ 93, 458]]], dtype=int32), array([[[ 37, 457]],
#
#        [[ 38, 458]],
#
#        [[ 38, 461]],
#
#        [[ 37, 462]],
#
#        [[ 37, 464]],
#
#        [[ 38, 465]],
#
#        [[ 38, 480]],
#
#        [[ 39, 481]],
#
#        [[ 39, 483]],
#
#        [[ 38, 484]],
#
#        [[ 37, 484]],
#
#        [[ 42, 484]],
#
#        [[ 42, 481]],
#
#        [[ 43, 480]],
#
#        [[ 44, 480]],
#
#        [[ 42, 480]],
#
#        [[ 41, 479]],
#
#        [[ 41, 470]],
#
#        [[ 40, 469]],
#
#        [[ 40, 468]],
#
#        [[ 41, 467]],
#
#        [[ 42, 467]],
#
#        [[ 41, 467]],
#
#        [[ 40, 466]],
#
#        [[ 40, 460]],
#
#        [[ 39, 460]],
#
#        [[ 38, 459]],
#
#        [[ 38, 458]]], dtype=int32), array([[[ 36, 443]]], dtype=int32), array([[[228, 442]],
#
#        [[229, 442]]], dtype=int32), array([[[ 31, 440]],
#
#        [[ 31, 441]],
#
#        [[ 32, 442]],
#
#        [[ 31, 441]]], dtype=int32), array([[[ 39, 429]],
#
#        [[ 40, 429]]], dtype=int32), array([[[564, 417]],
#
#        [[564, 419]]], dtype=int32), array([[[ 27, 415]],
#
#        [[ 27, 416]],
#
#        [[ 28, 417]],
#
#        [[ 28, 419]],
#
#        [[ 26, 421]],
#
#        [[ 25, 421]],
#
#        [[ 25, 424]],
#
#        [[ 23, 426]],
#
#        [[ 23, 428]],
#
#        [[ 24, 427]],
#
#        [[ 25, 428]],
#
#        [[ 26, 428]],
#
#        [[ 27, 429]],
#
#        [[ 27, 432]],
#
#        [[ 29, 434]],
#
#        [[ 29, 436]],
#
#        [[ 30, 436]],
#
#        [[ 31, 437]],
#
#        [[ 32, 437]],
#
#        [[ 34, 439]],
#
#        [[ 37, 439]],
#
#        [[ 37, 435]],
#
#        [[ 38, 434]],
#
#        [[ 38, 431]],
#
#        [[ 37, 430]],
#
#        [[ 37, 428]],
#
#        [[ 36, 427]],
#
#        [[ 36, 426]],
#
#        [[ 35, 425]],
#
#        [[ 35, 424]],
#
#        [[ 34, 424]],
#
#        [[ 33, 423]],
#
#        [[ 33, 421]],
#
#        [[ 31, 419]],
#
#        [[ 31, 417]],
#
#        [[ 28, 417]],
#
#        [[ 27, 416]],
#
#        [[ 28, 415]]], dtype=int32), array([[[ 36, 431]],
#
#        [[ 37, 430]],
#
#        [[ 38, 431]],
#
#        [[ 38, 432]],
#
#        [[ 37, 433]],
#
#        [[ 36, 432]]], dtype=int32), array([[[ 27, 431]],
#
#        [[ 28, 430]],
#
#        [[ 29, 431]],
#
#        [[ 29, 432]],
#
#        [[ 28, 433]],
#
#        [[ 27, 432]]], dtype=int32), array([[[ 35, 428]],
#
#        [[ 36, 427]],
#
#        [[ 37, 428]],
#
#        [[ 36, 429]]], dtype=int32), array([[[563, 414]]], dtype=int32), array([[[560, 414]]], dtype=int32), array([[[285, 414]],
#
#        [[286, 414]]], dtype=int32), array([[[135, 397]],
#
#        [[134, 398]],
#
#        [[134, 399]],
#
#        [[135, 400]],
#
#        [[137, 400]],
#
#        [[137, 398]],
#
#        [[136, 398]]], dtype=int32), array([[[121, 397]]], dtype=int32), array([[[126, 389]],
#
#        [[126, 390]],
#
#        [[125, 391]],
#
#        [[126, 390]],
#
#        [[127, 390]],
#
#        [[127, 389]]], dtype=int32), array([[[126, 387]],
#
#        [[127, 387]]], dtype=int32), array([[[ 79, 387]]], dtype=int32), array([[[410, 386]],
#
#        [[411, 387]],
#
#        [[412, 387]],
#
#        [[411, 386]]], dtype=int32), array([[[443, 383]],
#
#        [[443, 385]],
#
#        [[442, 386]],
#
#        [[441, 386]],
#
#        [[441, 387]],
#
#        [[442, 387]],
#
#        [[443, 388]],
#
#        [[443, 390]]], dtype=int32), array([[[126, 383]],
#
#        [[127, 383]]], dtype=int32), array([[[467, 378]],
#
#        [[467, 386]]], dtype=int32), array([[[467, 375]],
#
#        [[467, 376]]], dtype=int32), array([[[441, 375]],
#
#        [[441, 376]],
#
#        [[442, 376]],
#
#        [[442, 375]]], dtype=int32), array([[[403, 375]],
#
#        [[403, 381]],
#
#        [[405, 381]],
#
#        [[407, 383]],
#
#        [[406, 384]],
#
#        [[406, 386]],
#
#        [[405, 387]],
#
#        [[403, 387]],
#
#        [[402, 386]],
#
#        [[402, 384]],
#
#        [[399, 384]],
#
#        [[399, 386]],
#
#        [[401, 386]],
#
#        [[402, 387]],
#
#        [[405, 387]],
#
#        [[406, 388]],
#
#        [[407, 388]],
#
#        [[407, 387]],
#
#        [[406, 386]],
#
#        [[406, 384]],
#
#        [[407, 383]],
#
#        [[406, 382]],
#
#        [[407, 381]],
#
#        [[409, 381]],
#
#        [[409, 380]],
#
#        [[406, 380]],
#
#        [[405, 379]],
#
#        [[405, 377]],
#
#        [[406, 376]],
#
#        [[407, 377]],
#
#        [[407, 375]]], dtype=int32), array([[[470, 374]]], dtype=int32), array([[[450, 374]],
#
#        [[450, 383]],
#
#        [[452, 383]],
#
#        [[452, 374]]], dtype=int32), array([[[459, 371]],
#
#        [[459, 372]],
#
#        [[460, 372]],
#
#        [[461, 373]],
#
#        [[460, 374]],
#
#        [[459, 374]],
#
#        [[459, 385]],
#
#        [[460, 385]],
#
#        [[460, 384]],
#
#        [[461, 383]],
#
#        [[461, 373]],
#
#        [[460, 372]],
#
#        [[460, 371]]], dtype=int32), array([[[416, 359]],
#
#        [[417, 360]],
#
#        [[417, 362]],
#
#        [[418, 362]],
#
#        [[419, 363]],
#
#        [[419, 364]],
#
#        [[420, 364]],
#
#        [[421, 365]],
#
#        [[421, 369]],
#
#        [[422, 370]],
#
#        [[423, 370]],
#
#        [[424, 371]],
#
#        [[424, 374]],
#
#        [[425, 374]],
#
#        [[424, 373]],
#
#        [[424, 371]],
#
#        [[423, 370]],
#
#        [[423, 365]],
#
#        [[422, 365]],
#
#        [[421, 364]],
#
#        [[421, 363]],
#
#        [[420, 362]],
#
#        [[420, 360]],
#
#        [[419, 360]],
#
#        [[418, 359]]], dtype=int32), array([[[240, 359]]], dtype=int32), array([[[401, 357]],
#
#        [[401, 358]]], dtype=int32), array([[[397, 357]],
#
#        [[397, 358]],
#
#        [[396, 359]],
#
#        [[394, 359]],
#
#        [[392, 361]],
#
#        [[390, 361]],
#
#        [[389, 360]],
#
#        [[388, 361]],
#
#        [[388, 370]],
#
#        [[387, 371]],
#
#        [[387, 376]],
#
#        [[386, 377]],
#
#        [[385, 377]],
#
#        [[385, 378]],
#
#        [[386, 378]],
#
#        [[387, 377]],
#
#        [[389, 377]],
#
#        [[389, 366]],
#
#        [[390, 365]],
#
#        [[391, 365]],
#
#        [[391, 364]],
#
#        [[392, 363]],
#
#        [[393, 363]],
#
#        [[394, 362]],
#
#        [[397, 362]],
#
#        [[397, 361]],
#
#        [[398, 360]],
#
#        [[400, 360]],
#
#        [[399, 360]],
#
#        [[397, 358]]], dtype=int32), array([[[531, 356]],
#
#        [[532, 356]]], dtype=int32), array([[[512, 356]]], dtype=int32), array([[[404, 356]],
#
#        [[403, 357]],
#
#        [[403, 358]],
#
#        [[407, 358]],
#
#        [[407, 357]],
#
#        [[408, 356]],
#
#        [[410, 356]]], dtype=int32), array([[[461, 341]]], dtype=int32), array([[[260, 337]],
#
#        [[260, 340]],
#
#        [[264, 340]],
#
#        [[264, 338]],
#
#        [[264, 339]],
#
#        [[263, 340]],
#
#        [[262, 340]],
#
#        [[261, 339]],
#
#        [[261, 337]]], dtype=int32), array([[[485, 332]],
#
#        [[485, 333]],
#
#        [[484, 334]],
#
#        [[482, 334]],
#
#        [[482, 335]],
#
#        [[480, 337]],
#
#        [[480, 340]],
#
#        [[479, 341]],
#
#        [[478, 340]],
#
#        [[477, 340]],
#
#        [[476, 339]],
#
#        [[476, 337]],
#
#        [[467, 337]],
#
#        [[466, 338]],
#
#        [[466, 339]],
#
#        [[465, 340]],
#
#        [[464, 340]],
#
#        [[463, 341]],
#
#        [[463, 342]],
#
#        [[470, 342]],
#
#        [[471, 343]],
#
#        [[471, 349]],
#
#        [[470, 350]],
#
#        [[471, 351]],
#
#        [[471, 353]],
#
#        [[475, 353]],
#
#        [[476, 354]],
#
#        [[475, 355]],
#
#        [[476, 356]],
#
#        [[475, 357]],
#
#        [[475, 358]],
#
#        [[476, 358]],
#
#        [[476, 357]],
#
#        [[477, 356]],
#
#        [[478, 356]],
#
#        [[479, 357]],
#
#        [[479, 358]],
#
#        [[479, 357]],
#
#        [[481, 355]],
#
#        [[482, 356]],
#
#        [[483, 356]],
#
#        [[484, 357]],
#
#        [[484, 358]],
#
#        [[489, 358]],
#
#        [[490, 359]],
#
#        [[497, 359]],
#
#        [[498, 358]],
#
#        [[498, 356]],
#
#        [[499, 355]],
#
#        [[499, 352]],
#
#        [[498, 351]],
#
#        [[498, 350]],
#
#        [[496, 350]],
#
#        [[495, 349]],
#
#        [[495, 348]],
#
#        [[493, 348]],
#
#        [[492, 347]],
#
#        [[491, 347]],
#
#        [[490, 348]],
#
#        [[487, 348]],
#
#        [[486, 347]],
#
#        [[486, 343]],
#
#        [[487, 342]],
#
#        [[488, 342]],
#
#        [[488, 338]],
#
#        [[487, 338]],
#
#        [[486, 337]],
#
#        [[486, 336]],
#
#        [[487, 335]],
#
#        [[489, 335]],
#
#        [[489, 334]],
#
#        [[490, 333]],
#
#        [[489, 333]],
#
#        [[488, 332]]], dtype=int32), array([[[495, 351]],
#
#        [[496, 350]],
#
#        [[497, 350]],
#
#        [[498, 351]],
#
#        [[497, 352]],
#
#        [[496, 352]]], dtype=int32), array([[[222, 328]],
#
#        [[222, 330]],
#
#        [[221, 331]],
#
#        [[219, 331]],
#
#        [[219, 336]],
#
#        [[221, 336]],
#
#        [[222, 337]],
#
#        [[225, 337]],
#
#        [[226, 338]],
#
#        [[226, 339]],
#
#        [[227, 340]],
#
#        [[226, 341]],
#
#        [[226, 342]],
#
#        [[225, 343]],
#
#        [[225, 344]],
#
#        [[226, 345]],
#
#        [[225, 346]],
#
#        [[225, 350]],
#
#        [[227, 352]],
#
#        [[227, 353]],
#
#        [[231, 353]],
#
#        [[233, 355]],
#
#        [[235, 355]],
#
#        [[236, 356]],
#
#        [[237, 355]],
#
#        [[241, 355]],
#
#        [[242, 356]],
#
#        [[243, 356]],
#
#        [[244, 355]],
#
#        [[250, 355]],
#
#        [[251, 354]],
#
#        [[253, 354]],
#
#        [[254, 353]],
#
#        [[254, 350]],
#
#        [[255, 349]],
#
#        [[258, 349]],
#
#        [[258, 348]],
#
#        [[259, 347]],
#
#        [[262, 347]],
#
#        [[262, 345]],
#
#        [[258, 345]],
#
#        [[257, 344]],
#
#        [[257, 342]],
#
#        [[256, 342]],
#
#        [[255, 341]],
#
#        [[256, 340]],
#
#        [[257, 340]],
#
#        [[256, 340]],
#
#        [[255, 339]],
#
#        [[255, 338]],
#
#        [[255, 339]],
#
#        [[254, 340]],
#
#        [[253, 339]],
#
#        [[253, 338]],
#
#        [[251, 338]],
#
#        [[251, 340]],
#
#        [[250, 341]],
#
#        [[249, 341]],
#
#        [[248, 340]],
#
#        [[247, 340]],
#
#        [[246, 339]],
#
#        [[246, 338]],
#
#        [[245, 338]],
#
#        [[245, 339]],
#
#        [[243, 341]],
#
#        [[242, 341]],
#
#        [[242, 342]],
#
#        [[243, 342]],
#
#        [[244, 343]],
#
#        [[244, 345]],
#
#        [[243, 346]],
#
#        [[242, 346]],
#
#        [[241, 347]],
#
#        [[240, 347]],
#
#        [[238, 345]],
#
#        [[237, 345]],
#
#        [[236, 344]],
#
#        [[236, 343]],
#
#        [[237, 342]],
#
#        [[238, 342]],
#
#        [[238, 340]],
#
#        [[237, 340]],
#
#        [[236, 339]],
#
#        [[236, 338]],
#
#        [[230, 338]],
#
#        [[229, 337]],
#
#        [[228, 337]],
#
#        [[226, 335]],
#
#        [[226, 334]],
#
#        [[225, 334]],
#
#        [[224, 333]],
#
#        [[225, 332]],
#
#        [[224, 333]],
#
#        [[223, 333]],
#
#        [[221, 331]],
#
#        [[222, 330]],
#
#        [[224, 330]],
#
#        [[224, 329]],
#
#        [[225, 328]]], dtype=int32), array([[[250, 341]],
#
#        [[253, 341]],
#
#        [[255, 343]],
#
#        [[255, 344]],
#
#        [[254, 345]],
#
#        [[254, 346]],
#
#        [[253, 347]],
#
#        [[250, 347]],
#
#        [[248, 345]],
#
#        [[248, 343]]], dtype=int32), array([[[244, 340]],
#
#        [[245, 339]],
#
#        [[246, 340]],
#
#        [[245, 341]]], dtype=int32), array([[[227, 340]],
#
#        [[228, 339]],
#
#        [[230, 339]],
#
#        [[231, 340]],
#
#        [[232, 340]],
#
#        [[233, 341]],
#
#        [[234, 341]],
#
#        [[235, 342]],
#
#        [[234, 343]],
#
#        [[233, 343]],
#
#        [[233, 344]],
#
#        [[231, 346]],
#
#        [[230, 345]],
#
#        [[228, 345]],
#
#        [[227, 344]]], dtype=int32), array([[[148, 317]],
#
#        [[147, 318]],
#
#        [[145, 318]],
#
#        [[144, 319]],
#
#        [[145, 320]],
#
#        [[145, 321]],
#
#        [[144, 322]],
#
#        [[144, 323]],
#
#        [[143, 324]],
#
#        [[143, 325]],
#
#        [[142, 326]],
#
#        [[143, 327]],
#
#        [[143, 328]],
#
#        [[144, 327]],
#
#        [[151, 327]],
#
#        [[152, 326]],
#
#        [[153, 326]],
#
#        [[153, 319]],
#
#        [[151, 317]],
#
#        [[150, 317]],
#
#        [[149, 318]]], dtype=int32), array([[[135, 317]],
#
#        [[133, 319]],
#
#        [[133, 322]],
#
#        [[135, 324]],
#
#        [[135, 325]],
#
#        [[137, 325]],
#
#        [[138, 326]],
#
#        [[139, 325]],
#
#        [[139, 317]]], dtype=int32), array([[[126, 310]],
#
#        [[125, 311]],
#
#        [[125, 313]],
#
#        [[124, 314]],
#
#        [[124, 317]],
#
#        [[123, 318]],
#
#        [[122, 318]],
#
#        [[122, 319]],
#
#        [[121, 320]],
#
#        [[121, 321]],
#
#        [[122, 322]],
#
#        [[121, 323]],
#
#        [[120, 323]],
#
#        [[121, 323]],
#
#        [[122, 322]],
#
#        [[127, 322]],
#
#        [[127, 318]],
#
#        [[128, 317]],
#
#        [[128, 315]],
#
#        [[129, 314]],
#
#        [[129, 313]],
#
#        [[128, 312]],
#
#        [[128, 310]]], dtype=int32), array([[[239, 297]],
#
#        [[239, 298]]], dtype=int32), array([[[613, 294]],
#
#        [[613, 295]],
#
#        [[612, 296]],
#
#        [[609, 296]],
#
#        [[608, 297]],
#
#        [[597, 297]],
#
#        [[597, 299]],
#
#        [[595, 301]],
#
#        [[595, 304]],
#
#        [[596, 305]],
#
#        [[600, 305]],
#
#        [[601, 304]],
#
#        [[603, 304]],
#
#        [[605, 306]],
#
#        [[605, 307]],
#
#        [[609, 307]],
#
#        [[609, 306]],
#
#        [[610, 305]],
#
#        [[612, 305]],
#
#        [[610, 305]],
#
#        [[609, 304]],
#
#        [[610, 303]],
#
#        [[614, 303]],
#
#        [[615, 302]],
#
#        [[619, 302]],
#
#        [[619, 300]],
#
#        [[620, 299]],
#
#        [[620, 296]],
#
#        [[618, 294]],
#
#        [[616, 294]],
#
#        [[615, 295]],
#
#        [[614, 294]]], dtype=int32), array([[[113, 294]],
#
#        [[113, 295]],
#
#        [[111, 297]],
#
#        [[110, 297]],
#
#        [[109, 296]],
#
#        [[108, 296]],
#
#        [[107, 297]],
#
#        [[105, 297]],
#
#        [[105, 298]],
#
#        [[104, 299]],
#
#        [[103, 299]],
#
#        [[103, 300]],
#
#        [[106, 300]],
#
#        [[107, 301]],
#
#        [[107, 302]],
#
#        [[109, 302]],
#
#        [[110, 303]],
#
#        [[110, 304]],
#
#        [[111, 304]],
#
#        [[112, 305]],
#
#        [[112, 299]],
#
#        [[113, 298]],
#
#        [[118, 298]],
#
#        [[118, 297]],
#
#        [[119, 296]],
#
#        [[117, 296]],
#
#        [[116, 295]],
#
#        [[117, 294]],
#
#        [[118, 294]]], dtype=int32), array([[[112, 296]],
#
#        [[113, 295]],
#
#        [[114, 295]],
#
#        [[115, 296]],
#
#        [[114, 297]],
#
#        [[113, 297]]], dtype=int32), array([[[500, 292]],
#
#        [[500, 293]],
#
#        [[501, 294]],
#
#        [[502, 294]],
#
#        [[502, 292]]], dtype=int32), array([[[486, 292]],
#
#        [[486, 293]],
#
#        [[489, 293]],
#
#        [[489, 292]]], dtype=int32), array([[[ 59, 292]],
#
#        [[ 59, 293]]], dtype=int32), array([[[503, 290]],
#
#        [[504, 291]]], dtype=int32), array([[[ 55, 289]],
#
#        [[ 55, 291]],
#
#        [[ 54, 292]],
#
#        [[ 53, 292]],
#
#        [[ 52, 291]],
#
#        [[ 51, 292]],
#
#        [[ 51, 293]],
#
#        [[ 52, 294]],
#
#        [[ 52, 296]],
#
#        [[ 53, 297]],
#
#        [[ 53, 298]],
#
#        [[ 55, 298]],
#
#        [[ 56, 299]],
#
#        [[ 56, 303]],
#
#        [[ 58, 303]],
#
#        [[ 59, 304]],
#
#        [[ 60, 304]],
#
#        [[ 61, 305]],
#
#        [[ 64, 305]],
#
#        [[ 65, 306]],
#
#        [[ 65, 307]],
#
#        [[ 65, 306]],
#
#        [[ 66, 305]],
#
#        [[ 67, 305]],
#
#        [[ 68, 304]],
#
#        [[ 69, 305]],
#
#        [[ 69, 307]],
#
#        [[ 68, 308]],
#
#        [[ 69, 309]],
#
#        [[ 69, 313]],
#
#        [[ 70, 313]],
#
#        [[ 71, 314]],
#
#        [[ 73, 314]],
#
#        [[ 74, 315]],
#
#        [[ 74, 316]],
#
#        [[ 78, 316]],
#
#        [[ 79, 317]],
#
#        [[ 86, 317]],
#
#        [[ 87, 316]],
#
#        [[ 88, 316]],
#
#        [[ 89, 317]],
#
#        [[ 91, 317]],
#
#        [[ 91, 315]],
#
#        [[ 92, 314]],
#
#        [[ 92, 313]],
#
#        [[ 93, 312]],
#
#        [[ 94, 313]],
#
#        [[ 95, 313]],
#
#        [[ 94, 313]],
#
#        [[ 93, 312]],
#
#        [[ 93, 311]],
#
#        [[ 94, 310]],
#
#        [[ 96, 310]],
#
#        [[ 96, 308]],
#
#        [[ 97, 307]],
#
#        [[ 97, 303]],
#
#        [[ 96, 304]],
#
#        [[ 92, 304]],
#
#        [[ 92, 305]],
#
#        [[ 91, 306]],
#
#        [[ 91, 307]],
#
#        [[ 90, 308]],
#
#        [[ 89, 308]],
#
#        [[ 88, 307]],
#
#        [[ 88, 306]],
#
#        [[ 85, 306]],
#
#        [[ 84, 305]],
#
#        [[ 78, 305]],
#
#        [[ 77, 304]],
#
#        [[ 75, 304]],
#
#        [[ 73, 302]],
#
#        [[ 73, 301]],
#
#        [[ 72, 300]],
#
#        [[ 71, 300]],
#
#        [[ 70, 299]],
#
#        [[ 69, 299]],
#
#        [[ 68, 298]],
#
#        [[ 68, 297]],
#
#        [[ 66, 297]],
#
#        [[ 65, 296]],
#
#        [[ 64, 296]],
#
#        [[ 63, 297]],
#
#        [[ 62, 297]],
#
#        [[ 61, 296]],
#
#        [[ 60, 297]],
#
#        [[ 59, 296]],
#
#        [[ 57, 296]],
#
#        [[ 56, 295]],
#
#        [[ 56, 290]]], dtype=int32), array([[[509, 286]],
#
#        [[508, 287]],
#
#        [[508, 289]],
#
#        [[509, 290]],
#
#        [[512, 290]],
#
#        [[513, 289]],
#
#        [[515, 289]],
#
#        [[515, 287]],
#
#        [[514, 287]],
#
#        [[513, 286]]], dtype=int32), array([[[453, 285]]], dtype=int32), array([[[486, 283]],
#
#        [[486, 285]],
#
#        [[487, 286]],
#
#        [[487, 288]],
#
#        [[488, 288]],
#
#        [[490, 290]],
#
#        [[497, 290]],
#
#        [[496, 290]],
#
#        [[495, 289]],
#
#        [[495, 287]],
#
#        [[496, 286]],
#
#        [[497, 286]],
#
#        [[496, 286]],
#
#        [[495, 285]],
#
#        [[496, 284]],
#
#        [[498, 284]],
#
#        [[498, 283]],
#
#        [[495, 283]],
#
#        [[495, 284]],
#
#        [[494, 285]],
#
#        [[490, 285]],
#
#        [[489, 284]],
#
#        [[489, 283]]], dtype=int32), array([[[ 22, 283]],
#
#        [[ 22, 284]],
#
#        [[ 21, 285]],
#
#        [[ 18, 285]],
#
#        [[ 17, 286]],
#
#        [[ 16, 286]],
#
#        [[ 15, 287]],
#
#        [[ 15, 288]],
#
#        [[ 12, 291]],
#
#        [[ 11, 291]],
#
#        [[ 11, 293]],
#
#        [[  9, 295]],
#
#        [[  9, 298]],
#
#        [[ 10, 299]],
#
#        [[ 11, 298]],
#
#        [[ 13, 298]],
#
#        [[ 13, 297]],
#
#        [[ 16, 294]],
#
#        [[ 17, 294]],
#
#        [[ 18, 293]],
#
#        [[ 18, 292]],
#
#        [[ 19, 291]],
#
#        [[ 21, 291]],
#
#        [[ 21, 289]],
#
#        [[ 22, 288]]], dtype=int32), array([[[467, 282]],
#
#        [[467, 285]],
#
#        [[466, 286]],
#
#        [[467, 287]],
#
#        [[467, 288]],
#
#        [[469, 288]],
#
#        [[469, 287]],
#
#        [[470, 286]],
#
#        [[476, 286]],
#
#        [[475, 285]],
#
#        [[472, 285]],
#
#        [[471, 284]],
#
#        [[471, 283]],
#
#        [[470, 283]],
#
#        [[469, 282]]], dtype=int32), array([[[450, 277]],
#
#        [[450, 279]],
#
#        [[452, 279]],
#
#        [[452, 278]],
#
#        [[451, 277]]], dtype=int32), array([[[457, 276]],
#
#        [[458, 276]]], dtype=int32), array([[[226, 276]]], dtype=int32), array([[[255, 267]]], dtype=int32), array([[[459, 263]],
#
#        [[460, 263]]], dtype=int32), array([[[175, 263]],
#
#        [[174, 264]],
#
#        [[173, 264]],
#
#        [[173, 267]],
#
#        [[174, 267]],
#
#        [[175, 268]],
#
#        [[179, 268]],
#
#        [[179, 267]],
#
#        [[180, 266]],
#
#        [[179, 265]],
#
#        [[179, 264]],
#
#        [[178, 263]]], dtype=int32), array([[[449, 262]],
#
#        [[448, 263]],
#
#        [[449, 263]]], dtype=int32), array([[[ 31, 259]]], dtype=int32), array([[[458, 258]]], dtype=int32), array([[[188, 258]]], dtype=int32), array([[[149, 258]]], dtype=int32), array([[[189, 253]]], dtype=int32), array([[[436, 250]],
#
#        [[437, 250]]], dtype=int32), array([[[188, 250]],
#
#        [[187, 251]],
#
#        [[186, 251]],
#
#        [[186, 253]],
#
#        [[187, 253]],
#
#        [[187, 251]]], dtype=int32), array([[[ 52, 250]],
#
#        [[ 52, 253]],
#
#        [[ 53, 254]],
#
#        [[ 54, 254]],
#
#        [[ 55, 255]],
#
#        [[ 55, 257]],
#
#        [[ 56, 258]],
#
#        [[ 58, 258]],
#
#        [[ 59, 257]],
#
#        [[ 59, 251]],
#
#        [[ 57, 251]],
#
#        [[ 56, 250]]], dtype=int32), array([[[577, 241]],
#
#        [[577, 242]],
#
#        [[578, 242]],
#
#        [[578, 241]]], dtype=int32), array([[[ 55, 241]],
#
#        [[ 55, 242]],
#
#        [[ 54, 243]],
#
#        [[ 53, 243]],
#
#        [[ 54, 243]],
#
#        [[ 55, 244]],
#
#        [[ 56, 244]],
#
#        [[ 57, 245]],
#
#        [[ 60, 245]],
#
#        [[ 60, 244]],
#
#        [[ 58, 242]],
#
#        [[ 58, 241]]], dtype=int32), array([[[ 36, 240]]], dtype=int32), array([[[564, 237]],
#
#        [[564, 240]],
#
#        [[566, 240]],
#
#        [[567, 241]],
#
#        [[567, 242]],
#
#        [[568, 243]],
#
#        [[571, 243]],
#
#        [[572, 244]],
#
#        [[573, 243]],
#
#        [[572, 243]],
#
#        [[571, 242]],
#
#        [[571, 241]],
#
#        [[570, 241]],
#
#        [[569, 240]],
#
#        [[565, 240]],
#
#        [[564, 239]]], dtype=int32), array([[[154, 234]],
#
#        [[152, 236]],
#
#        [[149, 236]],
#
#        [[148, 237]],
#
#        [[143, 237]],
#
#        [[143, 238]],
#
#        [[142, 239]],
#
#        [[139, 239]],
#
#        [[138, 240]],
#
#        [[134, 240]],
#
#        [[133, 241]],
#
#        [[129, 241]],
#
#        [[129, 242]],
#
#        [[128, 243]],
#
#        [[127, 242]],
#
#        [[127, 241]],
#
#        [[125, 241]],
#
#        [[125, 242]],
#
#        [[124, 243]],
#
#        [[122, 243]],
#
#        [[122, 244]],
#
#        [[121, 245]],
#
#        [[122, 246]],
#
#        [[122, 247]],
#
#        [[123, 247]],
#
#        [[124, 248]],
#
#        [[124, 249]],
#
#        [[126, 251]],
#
#        [[126, 252]],
#
#        [[128, 252]],
#
#        [[129, 253]],
#
#        [[130, 253]],
#
#        [[131, 254]],
#
#        [[132, 254]],
#
#        [[133, 255]],
#
#        [[133, 256]],
#
#        [[134, 256]],
#
#        [[135, 257]],
#
#        [[137, 257]],
#
#        [[138, 258]],
#
#        [[146, 258]],
#
#        [[148, 256]],
#
#        [[151, 256]],
#
#        [[152, 257]],
#
#        [[153, 256]],
#
#        [[155, 256]],
#
#        [[155, 255]],
#
#        [[156, 254]],
#
#        [[157, 254]],
#
#        [[159, 252]],
#
#        [[160, 252]],
#
#        [[160, 251]],
#
#        [[162, 249]],
#
#        [[161, 248]],
#
#        [[161, 246]],
#
#        [[163, 244]],
#
#        [[164, 244]],
#
#        [[164, 243]],
#
#        [[165, 242]],
#
#        [[166, 243]],
#
#        [[166, 241]],
#
#        [[165, 240]],
#
#        [[165, 239]],
#
#        [[166, 238]],
#
#        [[167, 239]],
#
#        [[167, 237]],
#
#        [[166, 236]],
#
#        [[166, 235]],
#
#        [[165, 235]],
#
#        [[164, 234]]], dtype=int32), array([[[156, 253]],
#
#        [[157, 252]],
#
#        [[158, 253]],
#
#        [[157, 254]]], dtype=int32), array([[[160, 249]],
#
#        [[161, 248]],
#
#        [[162, 249]],
#
#        [[161, 250]]], dtype=int32), array([[[ 27, 225]],
#
#        [[ 26, 226]],
#
#        [[ 25, 226]],
#
#        [[ 25, 233]],
#
#        [[ 24, 234]],
#
#        [[ 23, 234]],
#
#        [[ 22, 235]],
#
#        [[ 20, 235]],
#
#        [[ 20, 236]],
#
#        [[ 19, 237]],
#
#        [[ 19, 245]],
#
#        [[ 18, 246]],
#
#        [[ 18, 258]],
#
#        [[ 19, 259]],
#
#        [[ 19, 263]],
#
#        [[ 18, 264]],
#
#        [[ 18, 265]],
#
#        [[ 17, 266]],
#
#        [[ 16, 266]],
#
#        [[ 16, 267]],
#
#        [[ 15, 268]],
#
#        [[ 16, 267]],
#
#        [[ 17, 267]],
#
#        [[ 19, 269]],
#
#        [[ 19, 270]],
#
#        [[ 20, 271]],
#
#        [[ 21, 271]],
#
#        [[ 22, 270]],
#
#        [[ 22, 269]],
#
#        [[ 23, 268]],
#
#        [[ 27, 268]],
#
#        [[ 28, 269]],
#
#        [[ 28, 270]],
#
#        [[ 29, 271]],
#
#        [[ 32, 271]],
#
#        [[ 33, 270]],
#
#        [[ 33, 268]],
#
#        [[ 34, 267]],
#
#        [[ 35, 267]],
#
#        [[ 35, 262]],
#
#        [[ 31, 262]],
#
#        [[ 30, 263]],
#
#        [[ 29, 263]],
#
#        [[ 28, 264]],
#
#        [[ 28, 265]],
#
#        [[ 27, 266]],
#
#        [[ 27, 267]],
#
#        [[ 26, 268]],
#
#        [[ 25, 268]],
#
#        [[ 23, 266]],
#
#        [[ 22, 266]],
#
#        [[ 21, 265]],
#
#        [[ 21, 262]],
#
#        [[ 20, 262]],
#
#        [[ 19, 261]],
#
#        [[ 19, 259]],
#
#        [[ 20, 258]],
#
#        [[ 21, 258]],
#
#        [[ 21, 254]],
#
#        [[ 20, 254]],
#
#        [[ 19, 253]],
#
#        [[ 19, 250]],
#
#        [[ 20, 249]],
#
#        [[ 21, 249]],
#
#        [[ 21, 245]],
#
#        [[ 22, 244]],
#
#        [[ 22, 243]],
#
#        [[ 23, 242]],
#
#        [[ 31, 242]],
#
#        [[ 31, 241]],
#
#        [[ 33, 239]],
#
#        [[ 32, 238]],
#
#        [[ 32, 237]],
#
#        [[ 31, 237]],
#
#        [[ 30, 236]],
#
#        [[ 29, 236]],
#
#        [[ 28, 235]],
#
#        [[ 29, 234]],
#
#        [[ 30, 234]],
#
#        [[ 30, 230]],
#
#        [[ 29, 230]],
#
#        [[ 27, 228]],
#
#        [[ 27, 226]],
#
#        [[ 28, 225]]], dtype=int32), array([[[ 22, 236]],
#
#        [[ 23, 235]],
#
#        [[ 24, 236]],
#
#        [[ 23, 237]]], dtype=int32), array([[[579, 222]],
#
#        [[579, 224]],
#
#        [[581, 224]],
#
#        [[582, 225]],
#
#        [[583, 225]],
#
#        [[583, 223]],
#
#        [[581, 223]],
#
#        [[580, 222]]], dtype=int32), array([[[470, 202]],
#
#        [[469, 203]],
#
#        [[464, 203]],
#
#        [[463, 204]],
#
#        [[462, 203]],
#
#        [[459, 203]],
#
#        [[458, 204]],
#
#        [[457, 204]],
#
#        [[457, 205]],
#
#        [[456, 206]],
#
#        [[454, 206]],
#
#        [[454, 210]],
#
#        [[455, 210]],
#
#        [[457, 212]],
#
#        [[458, 211]],
#
#        [[459, 212]],
#
#        [[465, 212]],
#
#        [[466, 213]],
#
#        [[469, 213]],
#
#        [[470, 214]],
#
#        [[470, 215]],
#
#        [[469, 216]],
#
#        [[464, 216]],
#
#        [[466, 216]],
#
#        [[467, 217]],
#
#        [[467, 219]],
#
#        [[468, 220]],
#
#        [[471, 220]],
#
#        [[472, 219]],
#
#        [[472, 218]],
#
#        [[473, 217]],
#
#        [[475, 217]],
#
#        [[475, 214]],
#
#        [[477, 212]],
#
#        [[478, 212]],
#
#        [[476, 212]],
#
#        [[474, 210]],
#
#        [[474, 209]],
#
#        [[473, 209]],
#
#        [[472, 208]],
#
#        [[472, 204]]], dtype=int32), array([[[ 27, 198]],
#
#        [[ 26, 199]],
#
#        [[ 25, 199]],
#
#        [[ 26, 199]]], dtype=int32), array([[[195, 195]],
#
#        [[195, 196]]], dtype=int32), array([[[ 25, 194]],
#
#        [[ 25, 196]],
#
#        [[ 26, 196]],
#
#        [[ 26, 194]]], dtype=int32), array([[[236, 193]],
#
#        [[235, 194]]], dtype=int32), array([[[222, 190]],
#
#        [[222, 191]],
#
#        [[221, 192]],
#
#        [[221, 193]],
#
#        [[221, 192]],
#
#        [[222, 191]],
#
#        [[224, 191]],
#
#        [[226, 193]],
#
#        [[226, 194]],
#
#        [[227, 194]],
#
#        [[224, 191]],
#
#        [[224, 190]]], dtype=int32), array([[[210, 189]],
#
#        [[209, 190]],
#
#        [[209, 193]],
#
#        [[211, 193]],
#
#        [[211, 189]]], dtype=int32), array([[[615, 188]],
#
#        [[615, 189]]], dtype=int32), array([[[610, 181]],
#
#        [[610, 184]]], dtype=int32), array([[[504, 174]],
#
#        [[503, 175]],
#
#        [[503, 176]],
#
#        [[502, 177]],
#
#        [[501, 177]],
#
#        [[501, 180]],
#
#        [[502, 180]],
#
#        [[503, 181]],
#
#        [[503, 182]],
#
#        [[504, 182]],
#
#        [[504, 181]],
#
#        [[505, 180]],
#
#        [[507, 180]],
#
#        [[508, 179]],
#
#        [[508, 176]],
#
#        [[507, 175]],
#
#        [[507, 174]]], dtype=int32), array([[[  9, 152]],
#
#        [[  9, 156]],
#
#        [[ 10, 157]],
#
#        [[ 10, 165]],
#
#        [[ 11, 166]],
#
#        [[ 12, 166]],
#
#        [[ 13, 167]],
#
#        [[ 13, 168]],
#
#        [[ 13, 167]],
#
#        [[ 14, 166]],
#
#        [[ 15, 166]],
#
#        [[ 15, 161]],
#
#        [[ 14, 160]],
#
#        [[ 14, 158]],
#
#        [[ 13, 157]],
#
#        [[ 13, 152]]], dtype=int32), array([[[609, 142]],
#
#        [[608, 143]],
#
#        [[601, 143]],
#
#        [[600, 144]],
#
#        [[598, 144]],
#
#        [[598, 145]],
#
#        [[596, 147]],
#
#        [[593, 147]],
#
#        [[592, 148]],
#
#        [[590, 148]],
#
#        [[589, 147]],
#
#        [[588, 147]],
#
#        [[588, 148]],
#
#        [[589, 148]],
#
#        [[590, 149]],
#
#        [[590, 150]],
#
#        [[589, 151]],
#
#        [[587, 151]],
#
#        [[586, 150]],
#
#        [[586, 149]],
#
#        [[586, 153]],
#
#        [[585, 154]],
#
#        [[584, 154]],
#
#        [[584, 159]],
#
#        [[583, 160]],
#
#        [[583, 164]],
#
#        [[582, 165]],
#
#        [[582, 174]],
#
#        [[583, 175]],
#
#        [[582, 176]],
#
#        [[585, 176]],
#
#        [[586, 177]],
#
#        [[586, 178]],
#
#        [[588, 180]],
#
#        [[589, 180]],
#
#        [[590, 181]],
#
#        [[590, 182]],
#
#        [[594, 182]],
#
#        [[595, 183]],
#
#        [[597, 183]],
#
#        [[598, 184]],
#
#        [[606, 184]],
#
#        [[607, 185]],
#
#        [[608, 185]],
#
#        [[608, 180]],
#
#        [[605, 180]],
#
#        [[604, 179]],
#
#        [[597, 179]],
#
#        [[596, 178]],
#
#        [[596, 177]],
#
#        [[594, 175]],
#
#        [[595, 174]],
#
#        [[594, 175]],
#
#        [[592, 175]],
#
#        [[591, 174]],
#
#        [[591, 172]],
#
#        [[592, 171]],
#
#        [[591, 170]],
#
#        [[591, 169]],
#
#        [[590, 168]],
#
#        [[590, 166]],
#
#        [[589, 165]],
#
#        [[589, 158]],
#
#        [[591, 156]],
#
#        [[591, 154]],
#
#        [[593, 152]],
#
#        [[594, 152]],
#
#        [[595, 151]],
#
#        [[597, 151]],
#
#        [[598, 152]],
#
#        [[599, 152]],
#
#        [[600, 151]],
#
#        [[601, 151]],
#
#        [[600, 150]],
#
#        [[600, 149]],
#
#        [[601, 148]],
#
#        [[613, 148]],
#
#        [[614, 149]],
#
#        [[614, 151]],
#
#        [[616, 153]],
#
#        [[617, 153]],
#
#        [[618, 154]],
#
#        [[618, 155]],
#
#        [[619, 156]],
#
#        [[619, 157]],
#
#        [[620, 158]],
#
#        [[620, 159]],
#
#        [[620, 147]],
#
#        [[619, 146]],
#
#        [[618, 147]],
#
#        [[615, 147]],
#
#        [[614, 146]],
#
#        [[611, 146]],
#
#        [[610, 145]],
#
#        [[610, 144]],
#
#        [[609, 144]],
#
#        [[608, 143]]], dtype=int32), array([[[597, 142]],
#
#        [[599, 142]]], dtype=int32), array([[[604, 140]],
#
#        [[604, 141]],
#
#        [[605, 141]],
#
#        [[605, 140]]], dtype=int32), array([[[595, 140]],
#
#        [[595, 141]]], dtype=int32), array([[[595, 130]],
#
#        [[595, 131]]], dtype=int32), array([[[302, 121]],
#
#        [[302, 122]],
#
#        [[301, 123]],
#
#        [[301, 125]],
#
#        [[300, 126]],
#
#        [[300, 128]],
#
#        [[299, 129]],
#
#        [[299, 153]],
#
#        [[300, 154]],
#
#        [[300, 156]],
#
#        [[303, 156]],
#
#        [[303, 154]],
#
#        [[305, 152]],
#
#        [[306, 153]],
#
#        [[306, 157]],
#
#        [[307, 158]],
#
#        [[307, 160]],
#
#        [[308, 160]],
#
#        [[309, 161]],
#
#        [[309, 165]],
#
#        [[310, 166]],
#
#        [[311, 165]],
#
#        [[313, 165]],
#
#        [[313, 163]],
#
#        [[314, 162]],
#
#        [[314, 161]],
#
#        [[316, 159]],
#
#        [[317, 159]],
#
#        [[317, 156]],
#
#        [[318, 155]],
#
#        [[318, 152]],
#
#        [[320, 150]],
#
#        [[321, 150]],
#
#        [[322, 151]],
#
#        [[323, 151]],
#
#        [[324, 152]],
#
#        [[323, 153]],
#
#        [[323, 155]],
#
#        [[321, 157]],
#
#        [[319, 157]],
#
#        [[319, 165]],
#
#        [[323, 165]],
#
#        [[324, 164]],
#
#        [[324, 162]],
#
#        [[325, 161]],
#
#        [[326, 161]],
#
#        [[326, 160]],
#
#        [[327, 159]],
#
#        [[327, 157]],
#
#        [[328, 156]],
#
#        [[328, 154]],
#
#        [[329, 153]],
#
#        [[329, 151]],
#
#        [[330, 150]],
#
#        [[331, 150]],
#
#        [[331, 148]],
#
#        [[332, 147]],
#
#        [[332, 146]],
#
#        [[333, 145]],
#
#        [[333, 132]],
#
#        [[332, 131]],
#
#        [[332, 130]],
#
#        [[330, 130]],
#
#        [[329, 129]],
#
#        [[329, 128]],
#
#        [[330, 127]],
#
#        [[332, 127]],
#
#        [[333, 128]],
#
#        [[336, 128]],
# ...
#
#        [[147,  87]],
#
#        [[147,  86]],
#
#        [[148,  85]],
#
#        [[149,  85]],
#
#        [[149,  84]],
#
#        [[148,  83]],
#
#        [[149,  82]],
#
#        [[149,  79]],
#
#        [[150,  78]],
#
#        [[151,  78]],
#
#        [[151,  77]],
#
#        [[152,  76]],
#
#        [[152,  75]],
#
#        [[153,  74]],
#
#        [[154,  75]],
#
#        [[154,  78]],
#
#        [[160,  78]],
#
#        [[162,  76]],
#
#        [[162,  75]],
#
#        [[161,  75]],
#
#        [[160,  74]],
#
#        [[157,  74]],
#
#        [[156,  73]]], dtype=int32), array([[[205,  72]],
#
#        [[205,  79]],
#
#        [[206,  79]],
#
#        [[207,  80]],
#
#        [[207,  81]],
#
#        [[207,  80]],
#
#        [[208,  79]],
#
#        [[209,  79]],
#
#        [[209,  75]],
#
#        [[208,  75]],
#
#        [[207,  74]],
#
#        [[207,  73]],
#
#        [[206,  72]]], dtype=int32), array([[[ 99,  72]],
#
#        [[100,  72]]], dtype=int32), array([[[343,  68]],
#
#        [[343,  69]],
#
#        [[342,  70]],
#
#        [[341,  69]],
#
#        [[339,  69]],
#
#        [[341,  69]],
#
#        [[342,  70]],
#
#        [[342,  71]],
#
#        [[342,  70]],
#
#        [[343,  69]]], dtype=int32), array([[[288,  68]],
#
#        [[288,  69]],
#
#        [[287,  70]],
#
#        [[287,  71]],
#
#        [[286,  72]],
#
#        [[287,  72]],
#
#        [[288,  73]],
#
#        [[288,  74]],
#
#        [[289,  74]],
#
#        [[290,  75]],
#
#        [[290,  76]],
#
#        [[290,  75]],
#
#        [[291,  74]],
#
#        [[292,  74]],
#
#        [[292,  69]],
#
#        [[291,  68]]], dtype=int32), array([[[295,  65]],
#
#        [[295,  76]]], dtype=int32), array([[[103,  65]],
#
#        [[102,  66]],
#
#        [[102,  68]],
#
#        [[101,  69]],
#
#        [[ 99,  69]],
#
#        [[101,  69]],
#
#        [[102,  70]],
#
#        [[102,  71]],
#
#        [[102,  70]],
#
#        [[103,  69]],
#
#        [[106,  69]],
#
#        [[107,  70]],
#
#        [[107,  71]],
#
#        [[109,  71]],
#
#        [[109,  70]],
#
#        [[108,  70]],
#
#        [[107,  69]],
#
#        [[108,  68]],
#
#        [[109,  68]],
#
#        [[107,  68]],
#
#        [[106,  67]],
#
#        [[106,  66]],
#
#        [[105,  65]]], dtype=int32), array([[[615,  63]]], dtype=int32), array([[[618,  61]],
#
#        [[618,  62]]], dtype=int32), array([[[336,  61]],
#
#        [[336,  63]],
#
#        [[337,  64]],
#
#        [[337,  67]],
#
#        [[341,  67]],
#
#        [[341,  66]],
#
#        [[342,  65]],
#
#        [[343,  65]],
#
#        [[344,  64]],
#
#        [[345,  64]],
#
#        [[346,  65]],
#
#        [[345,  64]],
#
#        [[345,  63]],
#
#        [[341,  63]],
#
#        [[340,  62]],
#
#        [[340,  61]]], dtype=int32), array([[[129,  59]]], dtype=int32), array([[[258,  57]],
#
#        [[258,  58]],
#
#        [[259,  59]],
#
#        [[259,  57]]], dtype=int32), array([[[133,  57]],
#
#        [[133,  58]]], dtype=int32), array([[[214,  55]],
#
#        [[215,  55]],
#
#        [[216,  56]],
#
#        [[216,  58]],
#
#        [[215,  59]],
#
#        [[214,  59]],
#
#        [[216,  59]],
#
#        [[217,  60]],
#
#        [[216,  61]],
#
#        [[216,  63]],
#
#        [[217,  63]],
#
#        [[218,  64]],
#
#        [[221,  64]],
#
#        [[223,  62]],
#
#        [[224,  62]],
#
#        [[224,  61]],
#
#        [[223,  61]],
#
#        [[220,  58]],
#
#        [[220,  57]],
#
#        [[219,  57]],
#
#        [[217,  55]],
#
#        [[216,  56]],
#
#        [[215,  55]]], dtype=int32), array([[[209,  51]],
#
#        [[210,  52]],
#
#        [[210,  54]],
#
#        [[212,  54]],
#
#        [[212,  52]],
#
#        [[211,  51]]], dtype=int32), array([[[262,  50]],
#
#        [[262,  56]],
#
#        [[263,  57]],
#
#        [[263,  58]],
#
#        [[266,  58]],
#
#        [[266,  57]],
#
#        [[267,  56]],
#
#        [[267,  55]],
#
#        [[266,  54]],
#
#        [[265,  54]],
#
#        [[264,  53]],
#
#        [[264,  52]]], dtype=int32), array([[[202,  50]],
#
#        [[202,  51]],
#
#        [[201,  52]],
#
#        [[199,  52]],
#
#        [[198,  51]],
#
#        [[196,  51]],
#
#        [[195,  52]],
#
#        [[194,  52]],
#
#        [[194,  54]],
#
#        [[193,  55]],
#
#        [[193,  59]],
#
#        [[192,  60]],
#
#        [[190,  60]],
#
#        [[189,  59]],
#
#        [[189,  57]],
#
#        [[181,  57]],
#
#        [[181,  59]],
#
#        [[180,  60]],
#
#        [[179,  59]],
#
#        [[178,  60]],
#
#        [[172,  60]],
#
#        [[171,  61]],
#
#        [[170,  61]],
#
#        [[170,  62]],
#
#        [[169,  63]],
#
#        [[168,  63]],
#
#        [[167,  64]],
#
#        [[166,  64]],
#
#        [[165,  65]],
#
#        [[162,  65]],
#
#        [[161,  66]],
#
#        [[159,  66]],
#
#        [[159,  68]],
#
#        [[158,  69]],
#
#        [[160,  69]],
#
#        [[161,  70]],
#
#        [[161,  71]],
#
#        [[162,  71]],
#
#        [[163,  72]],
#
#        [[163,  73]],
#
#        [[170,  73]],
#
#        [[171,  72]],
#
#        [[172,  72]],
#
#        [[173,  71]],
#
#        [[174,  71]],
#
#        [[174,  70]],
#
#        [[177,  67]],
#
#        [[178,  67]],
#
#        [[179,  68]],
#
#        [[180,  68]],
#
#        [[181,  67]],
#
#        [[181,  64]],
#
#        [[180,  63]],
#
#        [[180,  60]],
#
#        [[181,  59]],
#
#        [[182,  60]],
#
#        [[183,  60]],
#
#        [[184,  61]],
#
#        [[184,  64]],
#
#        [[186,  66]],
#
#        [[186,  67]],
#
#        [[187,  67]],
#
#        [[188,  68]],
#
#        [[188,  71]],
#
#        [[189,  71]],
#
#        [[189,  69]],
#
#        [[190,  68]],
#
#        [[190,  65]],
#
#        [[191,  64]],
#
#        [[192,  64]],
#
#        [[193,  63]],
#
#        [[194,  64]],
#
#        [[194,  65]],
#
#        [[195,  66]],
#
#        [[195,  67]],
#
#        [[199,  67]],
#
#        [[200,  68]],
#
#        [[201,  68]],
#
#        [[202,  69]],
#
#        [[204,  67]],
#
#        [[204,  66]],
#
#        [[203,  65]],
#
#        [[203,  64]],
#
#        [[199,  64]],
#
#        [[198,  63]],
#
#        [[198,  60]],
#
#        [[197,  59]],
#
#        [[197,  57]],
#
#        [[198,  56]],
#
#        [[199,  56]],
#
#        [[200,  55]],
#
#        [[204,  55]],
#
#        [[205,  56]],
#
#        [[206,  56]],
#
#        [[206,  54]],
#
#        [[205,  54]],
#
#        [[204,  53]],
#
#        [[204,  52]],
#
#        [[205,  51]],
#
#        [[207,  51]],
#
#        [[206,  50]]], dtype=int32), array([[[165,  72]],
#
#        [[166,  71]],
#
#        [[167,  72]],
#
#        [[166,  73]]], dtype=int32), array([[[164,  70]],
#
#        [[165,  69]],
#
#        [[166,  70]],
#
#        [[166,  71]],
#
#        [[165,  72]],
#
#        [[164,  71]]], dtype=int32), array([[[198,  65]],
#
#        [[199,  64]],
#
#        [[200,  65]],
#
#        [[199,  66]]], dtype=int32), array([[[192,  60]],
#
#        [[193,  59]],
#
#        [[194,  60]],
#
#        [[193,  61]]], dtype=int32), array([[[193,  56]],
#
#        [[194,  55]],
#
#        [[195,  56]],
#
#        [[194,  57]]], dtype=int32), array([[[158,  50]],
#
#        [[157,  51]],
#
#        [[157,  53]],
#
#        [[158,  54]],
#
#        [[161,  54]],
#
#        [[162,  55]],
#
#        [[163,  54]],
#
#        [[165,  54]],
#
#        [[166,  55]],
#
#        [[164,  57]],
#
#        [[159,  57]],
#
#        [[159,  58]],
#
#        [[157,  60]],
#
#        [[150,  60]],
#
#        [[149,  61]],
#
#        [[138,  61]],
#
#        [[138,  62]],
#
#        [[139,  63]],
#
#        [[138,  64]],
#
#        [[138,  67]],
#
#        [[140,  69]],
#
#        [[139,  70]],
#
#        [[139,  71]],
#
#        [[137,  73]],
#
#        [[136,  73]],
#
#        [[135,  72]],
#
#        [[135,  70]],
#
#        [[133,  70]],
#
#        [[133,  71]],
#
#        [[132,  72]],
#
#        [[130,  72]],
#
#        [[129,  73]],
#
#        [[125,  73]],
#
#        [[124,  74]],
#
#        [[122,  74]],
#
#        [[123,  74]],
#
#        [[124,  75]],
#
#        [[124,  76]],
#
#        [[128,  76]],
#
#        [[130,  78]],
#
#        [[130,  81]],
#
#        [[132,  81]],
#
#        [[132,  80]],
#
#        [[133,  79]],
#
#        [[133,  78]],
#
#        [[134,  77]],
#
#        [[134,  75]],
#
#        [[136,  73]],
#
#        [[137,  73]],
#
#        [[138,  72]],
#
#        [[141,  72]],
#
#        [[142,  71]],
#
#        [[144,  71]],
#
#        [[144,  70]],
#
#        [[143,  70]],
#
#        [[142,  69]],
#
#        [[144,  67]],
#
#        [[145,  68]],
#
#        [[146,  68]],
#
#        [[147,  67]],
#
#        [[148,  67]],
#
#        [[148,  66]],
#
#        [[149,  65]],
#
#        [[150,  66]],
#
#        [[150,  69]],
#
#        [[151,  69]],
#
#        [[151,  65]],
#
#        [[154,  62]],
#
#        [[157,  62]],
#
#        [[158,  63]],
#
#        [[160,  63]],
#
#        [[161,  62]],
#
#        [[164,  62]],
#
#        [[164,  61]],
#
#        [[165,  60]],
#
#        [[166,  60]],
#
#        [[167,  59]],
#
#        [[169,  59]],
#
#        [[169,  57]],
#
#        [[170,  56]],
#
#        [[172,  56]],
#
#        [[173,  57]],
#
#        [[173,  58]],
#
#        [[174,  58]],
#
#        [[174,  57]],
#
#        [[175,  56]],
#
#        [[176,  56]],
#
#        [[177,  55]],
#
#        [[178,  55]],
#
#        [[179,  54]],
#
#        [[179,  52]],
#
#        [[180,  51]],
#
#        [[176,  51]],
#
#        [[175,  52]],
#
#        [[175,  53]],
#
#        [[174,  54]],
#
#        [[172,  54]],
#
#        [[172,  55]],
#
#        [[171,  56]],
#
#        [[169,  54]],
#
#        [[169,  51]],
#
#        [[168,  51]],
#
#        [[167,  52]],
#
#        [[166,  51]],
#
#        [[163,  51]],
#
#        [[162,  50]]], dtype=int32), array([[[139,  66]],
#
#        [[140,  65]],
#
#        [[141,  65]],
#
#        [[142,  66]],
#
#        [[142,  67]],
#
#        [[141,  68]],
#
#        [[140,  68]],
#
#        [[139,  67]]], dtype=int32), array([[[173,  49]],
#
#        [[178,  49]]], dtype=int32), array([[[170,  49]]], dtype=int32), array([[[618,  47]],
#
#        [[618,  48]]], dtype=int32), array([[[203,  47]],
#
#        [[203,  48]]], dtype=int32), array([[[161,  47]],
#
#        [[161,  48]]], dtype=int32), array([[[200,  46]],
#
#        [[200,  48]],
#
#        [[201,  48]],
#
#        [[201,  46]]], dtype=int32), array([[[207,  41]]], dtype=int32), array([[[147,  41]]], dtype=int32), array([[[256,  40]],
#
#        [[256,  44]],
#
#        [[257,  44]],
#
#        [[257,  40]]], dtype=int32), array([[[134,  40]],
#
#        [[135,  40]]], dtype=int32), array([[[348,  38]],
#
#        [[348,  39]],
#
#        [[351,  39]],
#
#        [[351,  38]]], dtype=int32), array([[[254,  38]],
#
#        [[254,  41]]], dtype=int32), array([[[309,  36]],
#
#        [[308,  37]],
#
#        [[305,  37]],
#
#        [[305,  39]],
#
#        [[310,  39]],
#
#        [[310,  37]]], dtype=int32), array([[[128,  36]]], dtype=int32), array([[[203,  35]],
#
#        [[203,  36]]], dtype=int32), array([[[193,  35]],
#
#        [[193,  39]],
#
#        [[192,  40]],
#
#        [[191,  40]],
#
#        [[191,  41]],
#
#        [[190,  42]],
#
#        [[189,  42]],
#
#        [[188,  43]],
#
#        [[187,  42]],
#
#        [[187,  41]],
#
#        [[186,  41]],
#
#        [[185,  42]],
#
#        [[184,  42]],
#
#        [[184,  44]],
#
#        [[185,  44]],
#
#        [[186,  45]],
#
#        [[186,  46]],
#
#        [[185,  47]],
#
#        [[185,  48]],
#
#        [[183,  50]],
#
#        [[182,  50]],
#
#        [[182,  53]],
#
#        [[183,  53]],
#
#        [[184,  54]],
#
#        [[189,  54]],
#
#        [[190,  53]],
#
#        [[190,  50]],
#
#        [[191,  49]],
#
#        [[192,  49]],
#
#        [[193,  48]],
#
#        [[193,  45]],
#
#        [[194,  44]],
#
#        [[194,  43]],
#
#        [[195,  42]],
#
#        [[197,  42]],
#
#        [[198,  41]],
#
#        [[198,  38]],
#
#        [[200,  36]],
#
#        [[201,  36]],
#
#        [[201,  35]]], dtype=int32), array([[[480,  33]],
#
#        [[480,  34]]], dtype=int32), array([[[168,  33]],
#
#        [[168,  34]],
#
#        [[169,  34]],
#
#        [[169,  33]]], dtype=int32), array([[[188,  31]]], dtype=int32), array([[[556,  26]],
#
#        [[555,  27]],
#
#        [[546,  27]],
#
#        [[545,  28]],
#
#        [[541,  28]],
#
#        [[540,  29]],
#
#        [[538,  29]],
#
#        [[538,  31]],
#
#        [[541,  31]],
#
#        [[542,  32]],
#
#        [[541,  33]],
#
#        [[541,  36]],
#
#        [[540,  37]],
#
#        [[540,  39]],
#
#        [[542,  41]],
#
#        [[543,  41]],
#
#        [[544,  40]],
#
#        [[546,  40]],
#
#        [[547,  41]],
#
#        [[552,  41]],
#
#        [[553,  40]],
#
#        [[554,  40]],
#
#        [[555,  39]],
#
#        [[556,  40]],
#
#        [[557,  40]],
#
#        [[557,  38]],
#
#        [[556,  38]],
#
#        [[555,  37]],
#
#        [[555,  36]],
#
#        [[553,  34]],
#
#        [[553,  29]],
#
#        [[554,  28]],
#
#        [[555,  28]],
#
#        [[556,  29]],
#
#        [[556,  30]],
#
#        [[557,  30]],
#
#        [[558,  31]],
#
#        [[559,  31]],
#
#        [[558,  30]],
#
#        [[558,  26]]], dtype=int32), array([[[545,  35]],
#
#        [[547,  37]],
#
#        [[546,  38]],
#
#        [[546,  39]],
#
#        [[545,  40]],
#
#        [[544,  40]],
#
#        [[543,  39]],
#
#        [[543,  37]]], dtype=int32), array([[[541,  36]],
#
#        [[542,  35]],
#
#        [[543,  35]],
#
#        [[544,  36]],
#
#        [[543,  37]],
#
#        [[542,  37]]], dtype=int32), array([[[543,  32]],
#
#        [[544,  31]],
#
#        [[545,  32]],
#
#        [[544,  33]]], dtype=int32), array([[[565,  19]],
#
#        [[564,  20]],
#
#        [[564,  21]],
#
#        [[563,  22]],
#
#        [[563,  23]],
#
#        [[562,  24]],
#
#        [[561,  24]],
#
#        [[561,  32]],
#
#        [[562,  32]],
#
#        [[563,  33]],
#
#        [[563,  35]],
#
#        [[564,  36]],
#
#        [[566,  36]],
#
#        [[567,  35]],
#
#        [[568,  35]],
#
#        [[568,  32]],
#
#        [[569,  31]],
#
#        [[569,  20]],
#
#        [[568,  19]]], dtype=int32), array([[[365,  19]],
#
#        [[365,  21]],
#
#        [[368,  21]],
#
#        [[368,  20]],
#
#        [[367,  20]],
#
#        [[366,  19]]], dtype=int32), array([[[481,  18]]], dtype=int32), array([[[591,  14]],
#
#        [[590,  15]],
#
#        [[588,  15]],
#
#        [[588,  21]],
#
#        [[587,  22]],
#
#        [[587,  25]],
#
#        [[586,  26]],
#
#        [[586,  28]],
#
#        [[591,  28]],
#
#        [[591,  27]],
#
#        [[592,  26]],
#
#        [[592,  24]],
#
#        [[593,  23]],
#
#        [[595,  23]],
#
#        [[596,  22]],
#
#        [[597,  23]],
#
#        [[603,  23]],
#
#        [[604,  24]],
#
#        [[604,  25]],
#
#        [[606,  25]],
#
#        [[607,  26]],
#
#        [[613,  26]],
#
#        [[613,  24]],
#
#        [[612,  23]],
#
#        [[611,  23]],
#
#        [[610,  22]],
#
#        [[609,  22]],
#
#        [[608,  21]],
#
#        [[608,  20]],
#
#        [[607,  20]],
#
#        [[606,  19]],
#
#        [[607,  18]],
#
#        [[608,  18]],
#
#        [[608,  17]],
#
#        [[607,  17]],
#
#        [[606,  16]],
#
#        [[606,  14]],
#
#        [[600,  14]],
#
#        [[599,  15]],
#
#        [[596,  15]],
#
#        [[596,  16]],
#
#        [[595,  17]],
#
#        [[594,  16]],
#
#        [[594,  14]]], dtype=int32), array([[[578,  14]],
#
#        [[578,  16]],
#
#        [[577,  17]],
#
#        [[575,  17]],
#
#        [[574,  18]],
#
#        [[574,  23]],
#
#        [[573,  24]],
#
#        [[573,  30]],
#
#        [[574,  31]],
#
#        [[574,  32]],
#
#        [[576,  32]],
#
#        [[576,  31]],
#
#        [[577,  30]],
#
#        [[577,  29]],
#
#        [[576,  28]],
#
#        [[576,  24]],
#
#        [[577,  23]],
#
#        [[577,  20]],
#
#        [[578,  19]],
#
#        [[579,  20]],
#
#        [[579,  23]],
#
#        [[580,  23]],
#
#        [[581,  24]],
#
#        [[581,  26]],
#
#        [[580,  27]],
#
#        [[579,  27]],
#
#        [[580,  27]],
#
#        [[581,  28]],
#
#        [[581,  30]],
#
#        [[583,  30]],
#
#        [[583,  29]],
#
#        [[582,  28]],
#
#        [[582,  27]],
#
#        [[581,  26]],
#
#        [[582,  25]],
#
#        [[582,  22]],
#
#        [[581,  21]],
#
#        [[581,  20]],
#
#        [[583,  18]],
#
#        [[585,  18]],
#
#        [[586,  17]],
#
#        [[586,  14]],
#
#        [[584,  14]],
#
#        [[583,  15]],
#
#        [[582,  15]],
#
#        [[581,  14]]], dtype=int32), array([[[435,  14]],
#
#        [[435,  16]],
#
#        [[436,  17]],
#
#        [[436,  22]],
#
#        [[437,  22]],
#
#        [[438,  23]],
#
#        [[438,  27]],
#
#        [[440,  27]],
#
#        [[441,  28]],
#
#        [[442,  28]],
#
#        [[444,  26]],
#
#        [[445,  27]],
#
#        [[446,  27]],
#
#        [[445,  27]],
#
#        [[444,  26]],
#
#        [[445,  25]],
#
#        [[447,  25]],
#
#        [[447,  24]],
#
#        [[449,  22]],
#
#        [[453,  22]],
#
#        [[453,  19]],
#
#        [[452,  18]],
#
#        [[452,  15]],
#
#        [[453,  14]],
#
#        [[454,  15]],
#
#        [[454,  16]],
#
#        [[456,  16]],
#
#        [[456,  15]],
#
#        [[454,  15]],
#
#        [[453,  14]],
#
#        [[444,  14]],
#
#        [[443,  15]],
#
#        [[441,  15]],
#
#        [[440,  14]]], dtype=int32), array([[[440,  26]],
#
#        [[441,  25]],
#
#        [[443,  25]],
#
#        [[444,  26]],
#
#        [[442,  28]],
#
#        [[441,  28]],
#
#        [[440,  27]]], dtype=int32))
# Número de objetos rojos: 240
