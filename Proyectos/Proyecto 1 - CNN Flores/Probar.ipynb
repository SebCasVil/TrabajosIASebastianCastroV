# %% [markdown]
# # Probar CNN en múltiples carpetas
# * Lo primero es cargar el modelo ya entrenado
# * Después se abre una carpeta que contiene múltiples carpetas y se itera sobre cada una
# * Se imprime el nombre de la carpeta y se itera sobre las imagenes en cad carpeta
# * Se obtiene el arreglo de información de la imagen y se predice con el modelo
# * Se imprime la predicción

# %%
import tensorflow as tf
import os
from tensorflow.keras.preprocessing import image
import numpy as np

modelo = 'modeloDef5/'
model = tf.keras.models.load_model(modelo)
carpetaPruebas = 'C:/Users/kalan/Desktop/IA/Flores2/Generar/Pruebas4/'
carpetas = [f.path for f in os.scandir(carpetaPruebas) if f.is_dir()]
target_size = (200, 200)
for carpeta in carpetas:
    carpetaNombre = os.path.basename(carpeta)
    print(carpetaNombre)

    imagenes = [os.path.join(carpeta, f) for f in os.listdir(carpeta) if f.endswith('.jpg')]

    for imagen in imagenes:
        img = image.load_img(imagen, target_size=target_size)
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)

        predictions = model.predict(img_array)
        print("Prediccion para", os.path.basename(imagen), ":", predictions)

        class_labels = ["DienteAmarillo", "Girasol", "Lantana", "Lirio", "Vinca"]
        predicted_class_indices = np.argmax(predictions, axis=1)
        predicted_labels = [class_labels[i] for i in predicted_class_indices]

        print("Clase:", predicted_labels[0])

# 0 DienteAmarillo
# 1 Girasol
# 2 Lantana
# 3 Lirio
# 4 Vinca
# Out:
# WARNING:tensorflow:From c:\Users\kalan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From c:\Users\kalan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\kalan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:585: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# DienteAmarillo
# 1/1 [==============================] - 0s 305ms/step
# Prediccion para Prueba1.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 34ms/step
# Prediccion para Prueba2.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 33ms/step
# Prediccion para Prueba3.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 29ms/step
# Prediccion para Prueba4.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 33ms/step
# Prediccion para Prueba5.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# Girasol
# 1/1 [==============================] - 0s 29ms/step
# Prediccion para Prueba1.jpg : [[0. 1. 0. 0. 0.]]
# Predicted class: Girasol
# 1/1 [==============================] - 0s 26ms/step
# Prediccion para Prueba2.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 17ms/step
# Prediccion para Prueba3.jpg : [[0. 1. 0. 0. 0.]]
# Predicted class: Girasol
# 1/1 [==============================] - 0s 40ms/step
# Prediccion para Prueba4.jpg : [[0. 1. 0. 0. 0.]]
# Predicted class: Girasol
# 1/1 [==============================] - 0s 30ms/step
# Prediccion para Prueba5.jpg : [[0. 1. 0. 0. 0.]]
# Predicted class: Girasol
# Lantana
# 1/1 [==============================] - 0s 37ms/step
# Prediccion para Prueba1.jpg : [[0. 0. 1. 0. 0.]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 39ms/step
# Prediccion para Prueba2.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Prueba3.jpg : [[0. 0. 1. 0. 0.]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 38ms/step
# Prediccion para Prueba4.jpg : [[0. 0. 1. 0. 0.]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 45ms/step
# Prediccion para Prueba5.jpg : [[1.0000000e+00 0.0000000e+00 2.9516219e-24 0.0000000e+00 0.0000000e+00]]
# Predicted class: DienteAmarillo
# Lirio
# 1/1 [==============================] - 0s 35ms/step
# Prediccion para 1.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 38ms/step
# Prediccion para 2.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 50ms/step
# Prediccion para 3.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 26ms/step
# Prediccion para 4.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para 5.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# Profe
# 1/1 [==============================] - 0s 47ms/step
# Prediccion para flower-5326457_1920.jpg : [[0. 0. 1. 0. 0.]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para lantana-camara-dallas-red-hermosas-flores-rojas-y-naranjas-de-la-prolifica-lantana-roja-de-dallas-2d6tt86.jpg : [[0.0000000e+00 0.0000000e+00 1.0000000e+00 2.3252731e-08 0.0000000e+00]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Lantana.jpg : [[0. 0. 1. 0. 0.]]
# Predicted class: Lantana
# 1/1 [==============================] - 0s 15ms/step
# Prediccion para un-primer-plano-de-flores-de-lantana-roja-floreciendo-en-un-jardin-2f1t692.jpg : [[0. 0. 0. 1. 0.]]
# Predicted class: Lirio
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Vinca1.jpg : [[1. 0. 0. 0. 0.]]
# Predicted class: DienteAmarillo
# 1/1 [==============================] - 0s 29ms/step
# Prediccion para Vinca2.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Vinca3.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# Vinca
# 1/1 [==============================] - 0s 24ms/step
# Prediccion para Prueba1.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# 1/1 [==============================] - 0s 41ms/step
# Prediccion para Prueba2.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Prueba3.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# 1/1 [==============================] - 0s 31ms/step
# Prediccion para Prueba4.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
# 1/1 [==============================] - 0s 37ms/step
# Prediccion para Prueba5.jpg : [[0. 0. 0. 0. 1.]]
# Predicted class: Vinca
